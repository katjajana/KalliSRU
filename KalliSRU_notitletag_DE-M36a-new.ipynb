# %% [markdown]
# # Kalliope SRU Abfrage und parsen von MODS mit Python etree
# Quelle: https://github.com/deutsche-nationalbibliothek/dnblab/blob/main/DNB_SRU_Tutorial.ipynb

# %%
import requests
from lxml import etree
import pandas as pd

# %%
# SRU query
def kalliope_sru(query):
    base_url = "https://kalliope-verbund.info/sru"
    params = {
        'version': '1.2',
        'operation': 'searchRetrieve',
        'recordSchema': 'mods37',
        'maximumRecords': '100',
        'query': query
    }
    
    r = requests.get(base_url, params=params)
    mods_content = r.content
    records_mods = etree.fromstring(mods_content)
    
    # Check if more than 100 records
    if len(records_mods.xpath("//srw:record", namespaces={'srw': 'http://www.loc.gov/zing/srw/'})) < 100:
        return records_mods
    else:
        num_results = 100
        i = 101
        while num_results == 100:
            params.update({'startRecord': i})
            r = requests.get(base_url, params=params)
            new_mods_content = r.content
            new_records_mods = etree.fromstring(new_mods_content)
            records_mods.extend(new_records_mods.xpath("//srw:record", namespaces={'srw': 'http://www.loc.gov/zing/srw/'}))
            i += 100
            num_results = len(new_records_mods.xpath("//srw:record", namespaces={'srw': 'http://www.loc.gov/zing/srw/'}))
        
        return records_mods

# %%
def parse_mods(record):
    ns = {
        'srw': 'http://www.loc.gov/zing/srw/',  # SRW namespace
        'mods': 'http://www.loc.gov/mods/v3'    # MODS namespace
    }
    
    # Prüfen, ob der <title>-Tag leer ist
    #empty_title = record.xpath(".//mods:titleInfo/mods:title[not(node())]", namespaces=ns)
    empty_title = record.xpath(".//mods:relatedItem[@type='host']/mods:titleInfo/mods:title[not(node())]", namespaces=ns)
    #//mods:relatedItem[@type="host"]/mods:titleInfo[not(mods:title)]
    
    # Wenn der <title>-Tag nicht leer ist, diese Record überspringen
    if not empty_title:
        return None  # Überspringen, wenn kein leerer <title>-Tag
    
    # Falls leer, extrahiere andere Daten
    title = "empty"  # Da der Titel leer ist, setzen wir einen Platzhalter
    
    # Extract holder //mods/location/physicalLocation/@authority Physischer Standort (bestandshaltende Einrichtung)
    holder_elements = record.xpath(".//mods:location/mods:physicalLocation", namespaces=ns)    
    holder = holder_elements[0].text if holder_elements else "unknown"
        
    # Extract ISIL //mods/location/physicalLocation/@authorityURI
    ISILholder_elements = record.xpath(".//mods:location/mods:physicalLocation/@authorityURI", namespaces=ns)
    ISILholder = ISILholder_elements[0] if ISILholder_elements else "unknown"
    
    lang_attributes = record.xpath("//@lang", namespaces=ns)
    lang_attributes = lang_attributes[:3]  # Nur die ersten 3 Einträge, falls vorhanden
    
    name = record.xpath(".//mods:namePart/text()", namespaces=ns)
    nameID = record.xpath(".//mods:name/@authority", namespaces=ns)
    abstract_content = record.xpath(".//mods:abstract[@type='content']/text()", namespaces=ns)
    abstract_content = abstract_content[0] if abstract_content else 'NaN'
    
    recordID = record.xpath(".//mods:recordInfo/mods:recordIdentifier/text()", namespaces=ns)
   

    # Return a dictionary to build the DataFrame
    return {
        
        "Title": title,
        "holder": holder,
        "ISILholder": ISILholder,
        "langattributes": lang_attributes,
        "name": name,
        "nameID": nameID,
        "abstract_content": abstract_content
        "recordID": recordID
        
    }
# Out:
#   File "/tmp/ipykernel_1839893/1810029463.py", line 48
#     "recordID": recordID
#     ^
# SyntaxError: invalid syntax

# %%
# Example query
query = 'ead.repository.isil="DE-M36a"'
records_xml = kalliope_sru(query)

print(f'{len(records_xml.xpath("//srw:record", namespaces={"srw": "http://www.loc.gov/zing/srw/"}))} Ergebnisse gefunden')
# Out:
# 200 Ergebnisse gefunden

# %%
# query that ignores records with no empty title tag

records_xml = kalliope_sru(query)
records = records_xml.xpath("//srw:record", namespaces={'srw': 'http://www.loc.gov/zing/srw/'})
output = [parse_mods(record) for record in records if parse_mods(record) is not None]  # filter of empty title tag
df = pd.DataFrame(output)
df
# Out:
#    Title                                 holder  \
# 0  empty  Münchner Stadtbibliothek / Monacensia
# 1  empty  Münchner Stadtbibliothek / Monacensia
# 2  empty  Münchner Stadtbibliothek / Monacensia
# 3  empty  Münchner Stadtbibliothek / Monacensia
# 4  empty  Münchner Stadtbibliothek / Monacensia
# 5  empty  Münchner Stadtbibliothek / Monacensia
#
#                                           ISILholder   langattributes  \
# 0  http://ld.zdb-services.de/resource/organisations/  [ger, ger, ger]
# 1  http://ld.zdb-services.de/resource/organisations/  [ger, ger, ger]
# 2  http://ld.zdb-services.de/resource/organisations/  [ger, ger, ger]
# 3  http://ld.zdb-services.de/resource/organisations/  [ger, ger, ger]
# 4  http://ld.zdb-services.de/resource/organisations/  [ger, ger, ger]
# 5  http://ld.zdb-services.de/resource/organisations/  [ger, ger, ger]
#
#                                                 name            nameID  \
# 0                             [Bayerischer Rundfunk]          [DE-611]
# 1  [Münchner Stadtbibliothek / Monacensia, Münchn...  [DE-611, DE-588]
# 2                      [Karlinger, Hans (1882-1944)]          [DE-588]
# 3                         [Ille, Eduard (1823-1901)]          [DE-588]
# 4  [Münchner Stadtbibliothek / Monacensia, Münchn...          [DE-588]
# 5  [Reck-Malleczewen, Friedrich Percyval (1884-19...          [DE-588]
#
#                                     abstract_content
# 0                                                NaN
# 1  Umf. Diplome, Medaillen, Plaketten und Bilder ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN

# %%
print(etree.tostring(records_xml, pretty_print=True).decode())
# Out:
# <srw:searchRetrieveResponse xmlns:srw="http://www.loc.gov/zing/srw/" xmlns:srw_dc="info:srw/schema/1/dc-v1.1" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:diag="http://www.loc.gov/zing/srw/diagnostic/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:mods="http://www.loc.gov/mods/v3" xmlns:cld="http://www.ukoln.ac.uk/metadata/rslp/schema/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:my="http://www.infolytics.com/kopac" xmlns:eacNS="urn:isbn:1-931666-33-4">
#    <srw:version>1.2</srw:version>
#    <srw:numberOfRecords>303882</srw:numberOfRecords>
#    <srw:records>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93462</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-BF-93462</recordIdentifier>
#                   <recordChangeDate encoding="iso8601">20230116</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T17:48:39+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</recordContentSource>
#                   <languageOfCataloging>
#                      <languageTerm authority="iso639-2b" type="code" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/ger">ger</languageTerm>
#                      <languageTerm type="text" lang="ger">Deutsch</languageTerm>
#                   </languageOfCataloging>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611"/>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/</identifier>
#                   <titleInfo>
#                      <title/>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-93462</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93462</identifier>
#                   <titleInfo>
#                      <title>Bayerischer Rundfunk/Reventlow</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">mixed material</typeOfResource>
#                <name type="corporate" authority="DE-611" authorityURI="https://kalliope-verbund.info/agents/" valueURI="https://kalliope-verbund.info/agents/130321">
#                   <namePart>Bayerischer Rundfunk</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">Bestandsbildner</roleTerm>
#                   </role>
#                </name>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4128844-0" authority="DE-588">Sammlung</genre>
#                <titleInfo>
#                   <title>Bayerischer Rundfunk/Reventlow</title>
#                </titleInfo>
#                <location>
#                   <shelfLocator/>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>1 Archivkarton ; </extent>
#                </physicalDescription>
#                <note type="systemDetails">Nicht in EAD Vorhanden</note>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-4106333</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-4106333</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20230116</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20230116</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T17:48:39+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</recordContentSource>
#                   <languageOfCataloging>
#                      <languageTerm authority="iso639-2b" type="code" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/ger">ger</languageTerm>
#                      <languageTerm type="text" lang="ger">Deutsch</languageTerm>
#                   </languageOfCataloging>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-93462</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93462</identifier>
#                   <titleInfo>
#                      <title>Bayerischer Rundfunk/Reventlow</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-93462</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93462</identifier>
#                   <titleInfo>
#                      <title>Bayerischer Rundfunk/Reventlow</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">text</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/12090991X">
#                   <namePart>Wolffhardt, Rainer (1927-2017)</namePart>
#                   <role>
#                      <roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</roleTerm>
#                      <roleTerm type="text" lang="ger">Verfasser</roleTerm>
#                   </role>
#                </name>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/138990107">
#                   <namePart>Grunert, Manfred (1934-2011)</namePart>
#                   <role>
#                      <roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</roleTerm>
#                      <roleTerm type="text" lang="ger">Verfasser</roleTerm>
#                   </role>
#                </name>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/118600044">
#                   <namePart>Reventlow, Franziska zu (1871-1918)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">Dokumentiert</roleTerm>
#                   </role>
#                </name>
#                <name type="corporate" authority="DE-611" authorityURI="https://kalliope-verbund.info/agents/" valueURI="https://kalliope-verbund.info/agents/130321">
#                   <namePart>Bayerischer Rundfunk</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">Dokumentiert</roleTerm>
#                   </role>
#                </name>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4139988-2" authority="DE-588">Dokument</genre>
#                <titleInfo>
#                   <title>Konvolut Pressestimmen &#252;ber die Ausstellung zu Franziska zu Reventlow im Husumer Schloss</title>
#                </titleInfo>
#                <originInfo>
#                   <dateCreated encoding="w3cdtf" keyDate="yes" point="start">1980-12-22</dateCreated>
#                   <dateCreated>22.12.1980</dateCreated>
#                </originInfo>
#                <location>
#                   <shelfLocator>BRFR 14</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>1 Portr&#228;t zur dreiteiligen Fernsehproduktion 'Die Reventlow', 1 Portr&#228;t zur Dokumentation 'Franziska zu Reventlow. Versuch einer Ann&#228;herung' ; </extent>
#                </physicalDescription>
#                <note type="systemDetails">Handschrift</note>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-4161952</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-4161952</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20070207</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20230116</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T17:48:39+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</recordContentSource>
#                   <languageOfCataloging>
#                      <languageTerm authority="iso639-2b" type="code" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/ger">ger</languageTerm>
#                      <languageTerm type="text" lang="ger">Deutsch</languageTerm>
#                   </languageOfCataloging>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-93462</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93462</identifier>
#                   <titleInfo>
#                      <title>Bayerischer Rundfunk/Reventlow</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-93462</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93462</identifier>
#                   <titleInfo>
#                      <title>Bayerischer Rundfunk/Reventlow</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">mixed material</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/118600044">
#                   <namePart>Reventlow, Franziska zu (1871-1918)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">a [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/122845099">
#                   <namePart>H&#246;ffer, Donata (1949-)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">a [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4045895-7" authority="DE-588">Fotografie</genre>
#                <titleInfo>
#                   <title>Franziska zu Reventlow (Donata H&#246;ffer) m. Alexander (Henner Quest) u. Modell (Traude H&#246;ss) i. e. Szene a. d. Bayer. Fernsehenserie "Die Reventlow", 1. Teil, "Sprung i. d. Freiheit"</title>
#                </titleInfo>
#                <location>
#                   <shelfLocator>BRFR 1</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>S/W-Foto17.8 x 12.6 ; </extent>
#                </physicalDescription>
#                <note type="systemDetails">Nicht in EAD Vorhanden</note>
#                <accessCondition type="restrictionOnAccess">Benutzbar - Verf&#252;gbar, am Standort</accessCondition>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-4161953</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-4161953</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20070207</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20230116</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T17:48:39+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</recordContentSource>
#                   <languageOfCataloging>
#                      <languageTerm authority="iso639-2b" type="code" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/ger">ger</languageTerm>
#                      <languageTerm type="text" lang="ger">Deutsch</languageTerm>
#                   </languageOfCataloging>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-93462</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93462</identifier>
#                   <titleInfo>
#                      <title>Bayerischer Rundfunk/Reventlow</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-93462</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93462</identifier>
#                   <titleInfo>
#                      <title>Bayerischer Rundfunk/Reventlow</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">mixed material</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/118600044">
#                   <namePart>Reventlow, Franziska zu (1871-1918)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">a [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/116457392">
#                   <namePart>Reventlow, Rolf (1897-1981)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">a [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <name type="corporate" authority="DE-611" authorityURI="https://kalliope-verbund.info/agents/" valueURI="https://kalliope-verbund.info/agents/30102508">
#                   <namePart>Atelier D&#252;ll (M&#252;nchen)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">ur [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4045895-7" authority="DE-588">Fotografie</genre>
#                <titleInfo>
#                   <title>Franziska zu Reventlow mit Sohn Rolf in den Armen</title>
#                </titleInfo>
#                <location>
#                   <shelfLocator>BRFR 2</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>S/W-Foto17.8 x 12.6 ; </extent>
#                </physicalDescription>
#                <note type="systemDetails">Nicht in EAD Vorhanden</note>
#                <accessCondition type="restrictionOnAccess">Benutzbar - Verf&#252;gbar, am Standort</accessCondition>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-4161954</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-4161954</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20070207</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20230116</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T17:48:39+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</recordContentSource>
#                   <languageOfCataloging>
#                      <languageTerm authority="iso639-2b" type="code" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/ger">ger</languageTerm>
#                      <languageTerm type="text" lang="ger">Deutsch</languageTerm>
#                   </languageOfCataloging>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-93462</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93462</identifier>
#                   <titleInfo>
#                      <title>Bayerischer Rundfunk/Reventlow</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-93462</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93462</identifier>
#                   <titleInfo>
#                      <title>Bayerischer Rundfunk/Reventlow</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">mixed material</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/118600044">
#                   <namePart>Reventlow, Franziska zu (1871-1918)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">a [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/122845099">
#                   <namePart>H&#246;ffer, Donata (1949-)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">a [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4045895-7" authority="DE-588">Fotografie</genre>
#                <titleInfo>
#                   <title>Franziska zu Reventlow (Donata H&#246;ffer, rechts stehend) im Etablissement der Patronesse i. e. Szene a. d. Bayer. Fernsehenserie "Die Reventlow", 2. Teil, "Mit der Freiheit leben"</title>
#                </titleInfo>
#                <location>
#                   <shelfLocator>BRFR 3</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>S/W-Foto12.5 x 17.4 ; </extent>
#                </physicalDescription>
#                <note type="systemDetails">Nicht in EAD Vorhanden</note>
#                <accessCondition type="restrictionOnAccess">Benutzbar - Verf&#252;gbar, am Standort</accessCondition>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-4161955</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-4161955</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20070207</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20230116</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T17:48:39+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</recordContentSource>
#                   <languageOfCataloging>
#                      <languageTerm authority="iso639-2b" type="code" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/ger">ger</languageTerm>
#                      <languageTerm type="text" lang="ger">Deutsch</languageTerm>
#                   </languageOfCataloging>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-93462</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93462</identifier>
#                   <titleInfo>
#                      <title>Bayerischer Rundfunk/Reventlow</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-93462</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93462</identifier>
#                   <titleInfo>
#                      <title>Bayerischer Rundfunk/Reventlow</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">mixed material</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/118600044">
#                   <namePart>Reventlow, Franziska zu (1871-1918)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">a [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/11856269X">
#                   <namePart>Klages, Ludwig (1872-1956)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">a [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/116457392">
#                   <namePart>Reventlow, Rolf (1897-1981)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">a [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/122845099">
#                   <namePart>H&#246;ffer, Donata (1949-)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">a [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4045895-7" authority="DE-588">Fotografie</genre>
#                <titleInfo>
#                   <title>Franziska zu Reventlow (Donata H&#246;ffer) m. Ludwig Klages (Klaus Gr&#252;nberg) u. Sohn Rolf (Rolf v. Z&#252;ndt) i. e. Szene a. d. Bayer. Fernsehenserie "Die Reventlow", 3. Teil "Rausch und Befreiung"</title>
#                </titleInfo>
#                <location>
#                   <shelfLocator>BRFR 4</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>S/W-Foto12.6 x 17.6 ; </extent>
#                </physicalDescription>
#                <note type="systemDetails">Nicht in EAD Vorhanden</note>
#                <accessCondition type="restrictionOnAccess">Benutzbar - Verf&#252;gbar, am Standort</accessCondition>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-4161956</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-4161956</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20070207</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20230116</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T17:48:39+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</recordContentSource>
#                   <languageOfCataloging>
#                      <languageTerm authority="iso639-2b" type="code" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/ger">ger</languageTerm>
#                      <languageTerm type="text" lang="ger">Deutsch</languageTerm>
#                   </languageOfCataloging>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-93462</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93462</identifier>
#                   <titleInfo>
#                      <title>Bayerischer Rundfunk/Reventlow</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-93462</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93462</identifier>
#                   <titleInfo>
#                      <title>Bayerischer Rundfunk/Reventlow</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">mixed material</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/118600044">
#                   <namePart>Reventlow, Franziska zu (1871-1918)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">a [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/118634976">
#                   <namePart>Wolfskehl, Karl (1869-1948)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">a [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/122845099">
#                   <namePart>H&#246;ffer, Donata (1949-)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">a [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4045895-7" authority="DE-588">Fotografie</genre>
#                <titleInfo>
#                   <title>Franziska zu Reventlow (Donata H&#246;ffer) u. Karl Wolfskehl (Hermann Treusch) i. e. Szene a. d. Bayer. Fernsehenserie "Die Reventlow", 3. Teil, "Rausch und Befreiung"</title>
#                </titleInfo>
#                <location>
#                   <shelfLocator>BRFR 5</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>S/W-Foto12.6 x 17.6 ; </extent>
#                </physicalDescription>
#                <note type="systemDetails">Nicht in EAD Vorhanden</note>
#                <accessCondition type="restrictionOnAccess">Benutzbar - Verf&#252;gbar, am Standort</accessCondition>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-4162316</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-4162316</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20070207</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20230116</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T17:48:39+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</recordContentSource>
#                   <languageOfCataloging>
#                      <languageTerm authority="iso639-2b" type="code" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/ger">ger</languageTerm>
#                      <languageTerm type="text" lang="ger">Deutsch</languageTerm>
#                   </languageOfCataloging>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-93462</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93462</identifier>
#                   <titleInfo>
#                      <title>Bayerischer Rundfunk/Reventlow</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-93462</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93462</identifier>
#                   <titleInfo>
#                      <title>Bayerischer Rundfunk/Reventlow</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">mixed material</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/118600044">
#                   <namePart>Reventlow, Franziska zu (1871-1918)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">a [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/118634976">
#                   <namePart>Wolfskehl, Karl (1869-1948)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">a [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/122845099">
#                   <namePart>H&#246;ffer, Donata (1949-)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">a [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4045895-7" authority="DE-588">Fotografie</genre>
#                <titleInfo>
#                   <title>Franziska zu Reventlow (Donata H&#246;ffer) u. Karl Wolfskehl (Hermann Treusch) u.a. i. e. Szene (Bacchantisches Fest) a. d. Bayer. Fernsehenserie "Die Reventlow",3. Teil, "Rausch und Befreiung"</title>
#                </titleInfo>
#                <location>
#                   <shelfLocator>BRFR 6</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>S/W-Foto12.6 x 17.6 ; </extent>
#                </physicalDescription>
#                <note type="systemDetails">Nicht in EAD Vorhanden</note>
#                <accessCondition type="restrictionOnAccess">Benutzbar - Verf&#252;gbar, am Standort</accessCondition>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-4162317</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-4162317</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20070207</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20230116</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T17:48:39+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</recordContentSource>
#                   <languageOfCataloging>
#                      <languageTerm authority="iso639-2b" type="code" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/ger">ger</languageTerm>
#                      <languageTerm type="text" lang="ger">Deutsch</languageTerm>
#                   </languageOfCataloging>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-93462</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93462</identifier>
#                   <titleInfo>
#                      <title>Bayerischer Rundfunk/Reventlow</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-93462</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93462</identifier>
#                   <titleInfo>
#                      <title>Bayerischer Rundfunk/Reventlow</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">mixed material</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/118600044">
#                   <namePart>Reventlow, Franziska zu (1871-1918)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">a [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/141580461">
#                   <namePart>L&#252;bke, Walter (1861-1930)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">a [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/135283981">
#                   <namePart>Astan, Thomas</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">a [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4045895-7" authority="DE-588">Fotografie</genre>
#                <titleInfo>
#                   <title>Franziska zu Reventlow (Donata H&#246;ffer) m. Walter L&#252;bke (Thomas Astan) b. d. Hochzeit i. e. Szene a. d. Bayer. Fernsehenserie "Die Reventlow", 1. Teil, "Sprung i. d. Freiheit"</title>
#                </titleInfo>
#                <location>
#                   <shelfLocator>BRFR 7</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>S/W-Foto12.6 x 17.6 ; </extent>
#                </physicalDescription>
#                <note type="systemDetails">Nicht in EAD Vorhanden</note>
#                <accessCondition type="restrictionOnAccess">Benutzbar - Verf&#252;gbar, am Standort</accessCondition>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-4162318</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-4162318</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20070207</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20230116</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T17:48:39+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</recordContentSource>
#                   <languageOfCataloging>
#                      <languageTerm authority="iso639-2b" type="code" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/ger">ger</languageTerm>
#                      <languageTerm type="text" lang="ger">Deutsch</languageTerm>
#                   </languageOfCataloging>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-93462</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93462</identifier>
#                   <titleInfo>
#                      <title>Bayerischer Rundfunk/Reventlow</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-93462</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93462</identifier>
#                   <titleInfo>
#                      <title>Bayerischer Rundfunk/Reventlow</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">mixed material</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/118600044">
#                   <namePart>Reventlow, Franziska zu (1871-1918)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">a [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/122845099">
#                   <namePart>H&#246;ffer, Donata (1949-)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">a [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4045895-7" authority="DE-588">Fotografie</genre>
#                <titleInfo>
# ...
#                   <mods:dateCreated>30.08.1949</mods:dateCreated>
#                   <mods:place>
#                      <mods:placeTerm type="text">St. Gilgen</mods:placeTerm>
#                   </mods:place>
#                </mods:originInfo>
#                <mods:location>
#                   <mods:shelfLocator>FRM B 65</mods:shelfLocator>
#                   <mods:physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</mods:physicalLocation>
#                </mods:location>
#                <mods:physicalDescription>
#                   <mods:extent>1 Br.-Kt. ; </mods:extent>
#                </mods:physicalDescription>
#                <mods:note type="systemDetails">Handschrift</mods:note>
#             </mods:mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods:mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <mods:identifier type="uri">https://kalliope-verbund.info/DE-611-HS-4097935</mods:identifier>
#                <mods:recordInfo>
#                   <mods:recordIdentifier source="DE-611">DE-611-HS-4097935</mods:recordIdentifier>
#                   <mods:recordCreationDate encoding="iso8601">20151012</mods:recordCreationDate>
#                   <mods:recordChangeDate encoding="iso8601">20151012</mods:recordChangeDate>
#                   <mods:recordChangeDate encoding="w3cdtf">2024-03-29T17:15:28+01:00</mods:recordChangeDate>
#                   <mods:recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</mods:recordContentSource>
#                </mods:recordInfo>
#                <mods:relatedItem type="host">
#                   <mods:recordInfo>
#                      <mods:recordIdentifier source="DE-611">DE-611-BF-93353</mods:recordIdentifier>
#                   </mods:recordInfo>
#                   <mods:identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93353</mods:identifier>
#                   <mods:titleInfo>
#                      <mods:title>Briefe</mods:title>
#                   </mods:titleInfo>
#                </mods:relatedItem>
#                <mods:relatedItem type="series">
#                   <mods:recordInfo>
#                      <mods:recordIdentifier source="DE-611">DE-611-BF-93269</mods:recordIdentifier>
#                   </mods:recordInfo>
#                   <mods:identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93269</mods:identifier>
#                   <mods:titleInfo>
#                      <mods:title>Nachl. Reck-Malleczewen</mods:title>
#                   </mods:titleInfo>
#                </mods:relatedItem>
#                <mods:typeOfResource collection="yes">text</mods:typeOfResource>
#                <mods:name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/11855042X">
#                   <mods:namePart>Hesse, Hermann (1877-1962)</mods:namePart>
#                   <mods:role>
#                      <mods:roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</mods:roleTerm>
#                      <mods:roleTerm type="text" lang="ger">Verfasser</mods:roleTerm>
#                   </mods:role>
#                </mods:name>
#                <mods:name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/118598821">
#                   <mods:namePart>Reck-Malleczewen, Friedrich Percyval (1884-1945)</mods:namePart>
#                   <mods:role>
#                      <mods:roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/rcp">rcp</mods:roleTerm>
#                      <mods:roleTerm type="text" lang="ger">Adressat</mods:roleTerm>
#                   </mods:role>
#                </mods:name>
#                <mods:genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4008240-4" authority="DE-588">Brief</mods:genre>
#                <mods:titleInfo>
#                   <mods:title>Brief von Hermann Hesse an Friedrich Percyval Reck-Malleczewen, 21.03.1927</mods:title>
#                </mods:titleInfo>
#                <mods:originInfo>
#                   <mods:dateCreated encoding="w3cdtf" keyDate="yes" point="start">1927-03-21</mods:dateCreated>
#                   <mods:dateCreated>21.03.1927</mods:dateCreated>
#                   <mods:place>
#                      <mods:placeTerm type="text">Stuttgart</mods:placeTerm>
#                   </mods:place>
#                </mods:originInfo>
#                <mods:location>
#                   <mods:shelfLocator>FRM B 66</mods:shelfLocator>
#                   <mods:physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</mods:physicalLocation>
#                </mods:location>
#                <mods:physicalDescription>
#                   <mods:extent>1 Kt. ; </mods:extent>
#                </mods:physicalDescription>
#                <mods:note type="systemDetails">Handschrift</mods:note>
#             </mods:mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods:mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <mods:identifier type="uri">https://kalliope-verbund.info/DE-611-HS-4097936</mods:identifier>
#                <mods:recordInfo>
#                   <mods:recordIdentifier source="DE-611">DE-611-HS-4097936</mods:recordIdentifier>
#                   <mods:recordCreationDate encoding="iso8601">20151012</mods:recordCreationDate>
#                   <mods:recordChangeDate encoding="iso8601">20151012</mods:recordChangeDate>
#                   <mods:recordChangeDate encoding="w3cdtf">2024-03-29T17:15:28+01:00</mods:recordChangeDate>
#                   <mods:recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</mods:recordContentSource>
#                </mods:recordInfo>
#                <mods:relatedItem type="host">
#                   <mods:recordInfo>
#                      <mods:recordIdentifier source="DE-611">DE-611-BF-93353</mods:recordIdentifier>
#                   </mods:recordInfo>
#                   <mods:identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93353</mods:identifier>
#                   <mods:titleInfo>
#                      <mods:title>Briefe</mods:title>
#                   </mods:titleInfo>
#                </mods:relatedItem>
#                <mods:relatedItem type="series">
#                   <mods:recordInfo>
#                      <mods:recordIdentifier source="DE-611">DE-611-BF-93269</mods:recordIdentifier>
#                   </mods:recordInfo>
#                   <mods:identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93269</mods:identifier>
#                   <mods:titleInfo>
#                      <mods:title>Nachl. Reck-Malleczewen</mods:title>
#                   </mods:titleInfo>
#                </mods:relatedItem>
#                <mods:typeOfResource collection="yes">text</mods:typeOfResource>
#                <mods:name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/11855042X">
#                   <mods:namePart>Hesse, Hermann (1877-1962)</mods:namePart>
#                   <mods:role>
#                      <mods:roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</mods:roleTerm>
#                      <mods:roleTerm type="text" lang="ger">Verfasser</mods:roleTerm>
#                   </mods:role>
#                </mods:name>
#                <mods:name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/118598821">
#                   <mods:namePart>Reck-Malleczewen, Friedrich Percyval (1884-1945)</mods:namePart>
#                   <mods:role>
#                      <mods:roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/rcp">rcp</mods:roleTerm>
#                      <mods:roleTerm type="text" lang="ger">Adressat</mods:roleTerm>
#                   </mods:role>
#                </mods:name>
#                <mods:genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4008240-4" authority="DE-588">Brief</mods:genre>
#                <mods:titleInfo>
#                   <mods:title>Brief von Hermann Hesse an Friedrich Percyval Reck-Malleczewen, 02.04.1927</mods:title>
#                </mods:titleInfo>
#                <mods:originInfo>
#                   <mods:dateCreated encoding="w3cdtf" keyDate="yes" point="start">1927-04-02</mods:dateCreated>
#                   <mods:dateCreated>02.04.1927</mods:dateCreated>
#                   <mods:place>
#                      <mods:placeTerm type="text">Z&#252;rich</mods:placeTerm>
#                   </mods:place>
#                </mods:originInfo>
#                <mods:location>
#                   <mods:shelfLocator>FRM B 66</mods:shelfLocator>
#                   <mods:physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</mods:physicalLocation>
#                </mods:location>
#                <mods:physicalDescription>
#                   <mods:extent>1 Kt. ; </mods:extent>
#                </mods:physicalDescription>
#                <mods:note type="systemDetails">Handschrift</mods:note>
#             </mods:mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods:mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <mods:identifier type="uri">https://kalliope-verbund.info/DE-611-HS-4097937</mods:identifier>
#                <mods:recordInfo>
#                   <mods:recordIdentifier source="DE-611">DE-611-HS-4097937</mods:recordIdentifier>
#                   <mods:recordCreationDate encoding="iso8601">20151012</mods:recordCreationDate>
#                   <mods:recordChangeDate encoding="iso8601">20151012</mods:recordChangeDate>
#                   <mods:recordChangeDate encoding="w3cdtf">2024-03-29T17:15:28+01:00</mods:recordChangeDate>
#                   <mods:recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</mods:recordContentSource>
#                </mods:recordInfo>
#                <mods:relatedItem type="host">
#                   <mods:recordInfo>
#                      <mods:recordIdentifier source="DE-611">DE-611-BF-93353</mods:recordIdentifier>
#                   </mods:recordInfo>
#                   <mods:identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93353</mods:identifier>
#                   <mods:titleInfo>
#                      <mods:title>Briefe</mods:title>
#                   </mods:titleInfo>
#                </mods:relatedItem>
#                <mods:relatedItem type="series">
#                   <mods:recordInfo>
#                      <mods:recordIdentifier source="DE-611">DE-611-BF-93269</mods:recordIdentifier>
#                   </mods:recordInfo>
#                   <mods:identifier type="uri">https://kalliope-verbund.info/DE-611-BF-93269</mods:identifier>
#                   <mods:titleInfo>
#                      <mods:title>Nachl. Reck-Malleczewen</mods:title>
#                   </mods:titleInfo>
#                </mods:relatedItem>
#                <mods:typeOfResource collection="yes">text</mods:typeOfResource>
#                <mods:name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/101708122">
#                   <mods:namePart>Hirschfeld, Georg (1873-1942)</mods:namePart>
#                   <mods:role>
#                      <mods:roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</mods:roleTerm>
#                      <mods:roleTerm type="text" lang="ger">Verfasser</mods:roleTerm>
#                   </mods:role>
#                </mods:name>
#                <mods:name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/118598821">
#                   <mods:namePart>Reck-Malleczewen, Friedrich Percyval (1884-1945)</mods:namePart>
#                   <mods:role>
#                      <mods:roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/rcp">rcp</mods:roleTerm>
#                      <mods:roleTerm type="text" lang="ger">Adressat</mods:roleTerm>
#                   </mods:role>
#                </mods:name>
#                <mods:genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4008240-4" authority="DE-588">Brief</mods:genre>
#                <mods:titleInfo>
#                   <mods:title>Brief von Georg Hirschfeld an Friedrich Percyval Reck-Malleczewen, 15.01.1928</mods:title>
#                </mods:titleInfo>
#                <mods:originInfo>
#                   <mods:dateCreated encoding="w3cdtf" keyDate="yes" point="start">1928-01-15</mods:dateCreated>
#                   <mods:dateCreated>15.01.1928</mods:dateCreated>
#                   <mods:place>
#                      <mods:placeTerm type="text">M&#252;nchen</mods:placeTerm>
#                   </mods:place>
#                </mods:originInfo>
#                <mods:location>
#                   <mods:shelfLocator>FRM B 67</mods:shelfLocator>
#                   <mods:physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-M36a">M&#252;nchner Stadtbibliothek / Monacensia</mods:physicalLocation>
#                </mods:location>
#                <mods:physicalDescription>
#                   <mods:extent>1 Br. ; </mods:extent>
#                </mods:physicalDescription>
#                <mods:note type="systemDetails">Handschrift</mods:note>
#             </mods:mods>
#          </srw:recordData>
#       </srw:record>
#    </srw:searchRetrieveResponse>
