# %% [markdown]
# # Kalliope SRU Abfrage und parsen von MODS mit Python etree
# Quelle: https://github.com/deutsche-nationalbibliothek/dnblab/blob/main/DNB_SRU_Tutorial.ipynb

# %%
import requests
from lxml import etree
import pandas as pd

# %%
# SRU query
def kalliope_sru(query):
    base_url = "https://kalliope-verbund.info/sru"
    params = {
        'version': '1.2',
        'operation': 'searchRetrieve',
        'recordSchema': 'mods37',
        'maximumRecords': '100',
        'query': query
    }
    
    r = requests.get(base_url, params=params)
    mods_content = r.content
    records_mods = etree.fromstring(mods_content)
    
    # Check if more than 100 records
    if len(records_mods.xpath("//srw:record", namespaces={'srw': 'http://www.loc.gov/zing/srw/'})) < 100:
        return records_mods
    else:
        num_results = 100
        i = 101
        while num_results == 100:
            params.update({'startRecord': i})
            r = requests.get(base_url, params=params)
            new_mods_content = r.content
            new_records_mods = etree.fromstring(new_mods_content)
            records_mods.extend(new_records_mods.xpath("//srw:record", namespaces={'srw': 'http://www.loc.gov/zing/srw/'}))
            i += 100
            num_results = len(new_records_mods.xpath("//srw:record", namespaces={'srw': 'http://www.loc.gov/zing/srw/'}))
        
        return records_mods

# %%
# function parse mods
def parse_mods(record):
    ns = {
        'srw': 'http://www.loc.gov/zing/srw/',  # SRW namespace
        'mods': 'http://www.loc.gov/mods/v3'    # MODS namespace
    }
    
    # Prüfen, ob der <title>-Tag leer ist
    empty_title = record.xpath(".//mods:titleInfo/mods:title[not(node())]", namespaces=ns)
    
    # Wenn der <title>-Tag nicht leer ist, diese Record überspringen
    if not empty_title:
        return None  # Überspringen, wenn kein leerer <title>-Tag
    
    # Falls leer, extrahiere andere Daten
    try:
        title = empty_title[0].text
    except IndexError:
        title = "unknown"
    
    # Extract holder //mods/location/physicalLocation/@authority Physischer Standort (bestandshaltende Einrichtung)
    holder = record.xpath(".//mods:location/mods:physicalLocation", namespaces=ns)    
    try:
        holder = holder[0].text
    except IndexError:
        holder = "unknown"
        
    # Extract ISIL //mods/location/physicalLocation/@authority Physischer Standort (bestandshaltende Einrichtung)
    ISILholder = record.xpath(".//mods:location/mods:physicalLocation/@authorityURI", namespaces=ns)
    
    lang_attributes = record.xpath("//@lang")
    try:
        lang_attributes = lang_attributes[:3] #only first 4 entries
    except IndexError:
        lang_attributes = "unknown"
    
    name = record.xpath(".//mods:namePart/text()", namespaces=ns)
    nameID = record.xpath(".//mods:name/@authority", namespaces=ns)
    abstract_content = record.xpath(".//mods:abstract[@type='content']/text()", namespaces=ns)
    abstract_content = abstract_content[0] if abstract_content else 'NaN'

    # Return a dictionary to build the DataFrame
    return {
        "Title": title,
        "holder": holder,
        "ISILholder": ISILholder,
        "langattributes": lang_attributes,
        "name": name,
        "nameID": nameID,
        "abstract_content": abstract_content
    }

# %%
# Example query
query = 'ead.repository.isil="DE-1a"'
records_xml = kalliope_sru(query)

print(f'{len(records_xml.xpath("//srw:record", namespaces={"srw": "http://www.loc.gov/zing/srw/"}))} Ergebnisse gefunden')
# Out:
# 200 Ergebnisse gefunden

# %%
# query that ignores records with no empty title tag

records_xml = kalliope_sru(query)
records = records_xml.xpath("//srw:record", namespaces={'srw': 'http://www.loc.gov/zing/srw/'})
output = [parse_mods(record) for record in records if parse_mods(record) is not None]  # filter of empty title tag
df = pd.DataFrame(output)
df
# Out:
#    Title                                             holder  \
# 0   None  Staatsbibliothek zu Berlin. Handschriftenabtei...
# 1   None  Staatsbibliothek zu Berlin. Handschriftenabtei...
# 2   None  Staatsbibliothek zu Berlin. Handschriftenabtei...
# 3   None  Staatsbibliothek zu Berlin. Handschriftenabtei...
# 4   None  Staatsbibliothek zu Berlin. Handschriftenabtei...
# 5   None  Staatsbibliothek zu Berlin. Handschriftenabtei...
# 6   None  Staatsbibliothek zu Berlin. Handschriftenabtei...
# 7   None  Staatsbibliothek zu Berlin. Handschriftenabtei...
# 8   None  Staatsbibliothek zu Berlin. Handschriftenabtei...
# 9   None  Staatsbibliothek zu Berlin. Handschriftenabtei...
# 10  None  Staatsbibliothek zu Berlin. Handschriftenabtei...
# 11  None  Staatsbibliothek zu Berlin. Handschriftenabtei...
#
#                                            ISILholder   langattributes  \
# 0   [http://ld.zdb-services.de/resource/organisati...  [ger, ger, ger]
# 1   [http://ld.zdb-services.de/resource/organisati...  [ger, ger, ger]
# 2   [http://ld.zdb-services.de/resource/organisati...  [ger, ger, ger]
# 3   [http://ld.zdb-services.de/resource/organisati...  [ger, ger, ger]
# 4   [http://ld.zdb-services.de/resource/organisati...  [ger, ger, ger]
# 5   [http://ld.zdb-services.de/resource/organisati...  [ger, ger, ger]
# 6   [http://ld.zdb-services.de/resource/organisati...  [ger, ger, ger]
# 7   [http://ld.zdb-services.de/resource/organisati...  [ger, ger, ger]
# 8   [http://ld.zdb-services.de/resource/organisati...  [ger, ger, ger]
# 9   [http://ld.zdb-services.de/resource/organisati...  [ger, ger, ger]
# 10  [http://ld.zdb-services.de/resource/organisati...  [ger, ger, ger]
# 11  [http://ld.zdb-services.de/resource/organisati...  [ger, ger, ger]
#
#                                                  name  \
# 0                       [Grønbech, Kaare (1901-1957)]
# 1                      [Gurlitt, Wilhelm (1844-1905)]
# 2                                     [Schmidt, Carl]
# 3                    [Harnack, Adolf von (1851-1930)]
# 4                                      [Verschiedene]
# 5                                   [Lembcke, Anders]
# 6   [Gurlitt, Wilhelm (1844-1905), Gurlitt, Louis ...
# 7                      [Mommsen, Theodor (1817-1903)]
# 8               [Galle, Johann Gottfried (1812-1910)]
# 9                       [Buff, Charlotte (1753-1828)]
# 10          [Savigny, Friedrich Carl von (1779-1861)]
# 11                                      [Mann, Oskar]
#
#                                       nameID  \
# 0                                   [DE-588]
# 1                                   [DE-588]
# 2                                   [DE-588]
# 3                                   [DE-588]
# 4                                   [DE-611]
# 5                                   [DE-588]
# 6   [DE-588, DE-588, DE-588, DE-611, DE-588]
# 7                                   [DE-588]
# 8                                   [DE-588]
# 9                                   [DE-588]
# 10                                  [DE-588]
# 11                                  [DE-588]
#
#                                      abstract_content
# 0   Übersetzungen, Vorlesungsmanuskripte, Jakutisc...
# 1                                                 NaN
# 2   Manuskripte, Materialien u.a. zu Carl Schmidt ...
# 3   Personalpapiere, Ehrendiplome, Manuskripte, Ko...
# 4          Dokumente und Materialien zum 2. Weltkrieg
# 5   Teilnachlass mit Korrespondenzen u.a. Material...
# 6   Wilhelm Gurlitt, Mercedes Gurlitt und Familie:...
# 7                                                 NaN
# 8   Manuskripte, Korrespondenz, Konzepte von Vorle...
# 9                        70 Briefe von den Nachkommen
# 10  Die Nachlassergänzung umfasst umfangreiche Pri...
# 11  Manuskripte über persische und kurdische Sprac...

# %%
# print(etree.tostring(records_xml, pretty_print=True).decode())
# Out:
# <srw:searchRetrieveResponse xmlns:srw="http://www.loc.gov/zing/srw/" xmlns:srw_dc="info:srw/schema/1/dc-v1.1" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:diag="http://www.loc.gov/zing/srw/diagnostic/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:mods="http://www.loc.gov/mods/v3" xmlns:cld="http://www.ukoln.ac.uk/metadata/rslp/schema/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:my="http://www.infolytics.com/kopac" xmlns:eacNS="urn:isbn:1-931666-33-4">
#    <srw:version>1.2</srw:version>
#    <srw:numberOfRecords>46479</srw:numberOfRecords>
#    <srw:records>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-76593</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-BF-76593</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20200117</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20200117</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T16:38:35+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</recordContentSource>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611"/>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/</identifier>
#                   <titleInfo>
#                      <title/>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-76593</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-76593</identifier>
#                   <titleInfo>
#                      <title>Nachlass Stephan Reich</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">mixed material</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/123590736">
#                   <namePart>Reich, Stephan (1512-1588)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">Bestandsbildner</roleTerm>
#                   </role>
#                </name>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4128844-0" authority="DE-588">Sammlung</genre>
#                <titleInfo>
#                   <title>Nachlass Stephan Reich</title>
#                </titleInfo>
#                <location>
#                   <shelfLocator/>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</physicalLocation>
#                </location>
#                <note type="systemDetails">Nicht in EAD Vorhanden</note>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-72207</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-BF-72207</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20061218</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20200117</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T16:38:35+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</recordContentSource>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-76593</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-76593</identifier>
#                   <titleInfo>
#                      <title>Nachlass Stephan Reich</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-76593</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-76593</identifier>
#                   <titleInfo>
#                      <title>Nachlass Stephan Reich</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">mixed material</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/123590736">
#                   <namePart>Reich, Stephan (1512-1588)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">Bestandsbildner</roleTerm>
#                   </role>
#                </name>
#                <titleInfo>
#                   <title>Auslegungssammlung zu Weihnachtsliedern</title>
#                </titleInfo>
#                <abstract type="content">Christliche Auslegung vber etliche Geistliche lieder von der Heilwertigen geburt vnsers Herrn Jhesu Christi ...
# Von Stephan Reich eigenh&#228;ndig angelegte dt. Sammlung.
# Mit Inhaltsverzeichnis von Stephan Reich auf Bl. 16v.</abstract>
#                <originInfo>
#                   <dateCreated encoding="w3cdtf" keyDate="yes" point="start">1571</dateCreated>
#                   <dateCreated>1571</dateCreated>
#                </originInfo>
#                <location>
#                   <shelfLocator>Chart. B 319</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>1 Bd., III, 185 Bl. (Blatt II u. 182-185 sind leer); 20 x 15,5 cm ; </extent>
#                </physicalDescription>
#                <note>Manuskripttitel: Christliche Auslegung vber etliche Geistliche lieder von der Heilwertigen geburt vnsers Herrn Jhesu Christi ...</note>
#                <note type="systemDetails">Nicht in EAD Vorhanden</note>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-3412331</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-3412331</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20061218</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20090218</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T16:38:35+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</recordContentSource>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-72207</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-72207</identifier>
#                   <titleInfo>
#                      <title>Auslegungssammlung zu Weihnachtsliedern</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-76593</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-76593</identifier>
#                   <titleInfo>
#                      <title>Nachlass Stephan Reich</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">mixed material</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/123590736">
#                   <namePart>Reich, Stephan (1512-1588)</namePart>
#                   <role>
#                      <roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</roleTerm>
#                      <roleTerm type="text" lang="ger">Verfasser</roleTerm>
#                   </role>
#                </name>
#                <subject>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4120567-4" authority="DE-588">Kirchenlied</topic>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4189434-0" authority="DE-588">Weihnachtslied</topic>
#                   <topic lang="ger" authority="DE-611">Ein Kindlein so l&#246;blich</topic>
#                </subject>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <titleInfo>
#                   <title>Auslegung des Liedes "Ein Kindlein so l&#246;blich"</title>
#                </titleInfo>
#                <originInfo>
#                   <dateCreated encoding="w3cdtf" keyDate="yes" point="start">1571</dateCreated>
#                   <dateCreated>1571 [[1571]]</dateCreated>
#                </originInfo>
#                <location>
#                   <shelfLocator>Chart. B 319, Bl. 17r-57v</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>41 Bl ; </extent>
#                </physicalDescription>
#                <note type="systemDetails">Nicht in EAD Vorhanden</note>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-3412344</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-3412344</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20061219</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20090218</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T16:38:35+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</recordContentSource>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-72207</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-72207</identifier>
#                   <titleInfo>
#                      <title>Auslegungssammlung zu Weihnachtsliedern</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-76593</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-76593</identifier>
#                   <titleInfo>
#                      <title>Nachlass Stephan Reich</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">mixed material</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/123590736">
#                   <namePart>Reich, Stephan (1512-1588)</namePart>
#                   <role>
#                      <roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</roleTerm>
#                      <roleTerm type="text" lang="ger">Verfasser</roleTerm>
#                   </role>
#                </name>
#                <subject>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4120567-4" authority="DE-588">Kirchenlied</topic>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4189434-0" authority="DE-588">Weihnachtslied</topic>
#                   <topic lang="ger" authority="DE-611">Jesus Christus / Geburt</topic>
#                   <topic lang="ger" authority="DE-611">All' Ehr' und Lob soll Gottes sein</topic>
#                </subject>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <titleInfo>
#                   <title>Auslegung des Liedes "All' Ehr' und Lob soll Gottes sein"</title>
#                </titleInfo>
#                <originInfo>
#                   <dateCreated encoding="w3cdtf" keyDate="yes" point="start">1571</dateCreated>
#                   <dateCreated>1571 [[1571]]</dateCreated>
#                </originInfo>
#                <location>
#                   <shelfLocator>Chart. B 319, Bl. 58r-69r</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>12 Bl ; </extent>
#                </physicalDescription>
#                <note type="systemDetails">Nicht in EAD Vorhanden</note>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-3412346</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-3412346</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20061219</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20101022</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T16:38:35+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</recordContentSource>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-72207</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-72207</identifier>
#                   <titleInfo>
#                      <title>Auslegungssammlung zu Weihnachtsliedern</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-76593</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-76593</identifier>
#                   <titleInfo>
#                      <title>Nachlass Stephan Reich</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">mixed material</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/118716891">
#                   <namePart>Georg III., Anhalt, F&#252;rst (1507-1553)</namePart>
#                   <role>
#                      <roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</roleTerm>
#                      <roleTerm type="text" lang="ger">Verfasser</roleTerm>
#                   </role>
#                </name>
#                <subject>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4120567-4" authority="DE-588">Kirchenlied</topic>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4189434-0" authority="DE-588">Weihnachtslied</topic>
#                   <topic lang="ger" authority="DE-611">Jesus Christus / Geburt</topic>
#                   <topic lang="ger" authority="DE-611">All' Ehr' und Lob soll Gottes sein</topic>
#                </subject>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <titleInfo>
#                   <title>Auslegung des Lobgesangs der Engel [Auszug]</title>
#                   <subTitle>Eine Predigt von der Menschwerdung und Geburt unsers lieben Herrn Jesu Christi</subTitle>
#                </titleInfo>
#                <originInfo>
#                   <dateCreated encoding="w3cdtf" keyDate="yes" point="start">1552</dateCreated>
#                   <dateCreated>1552</dateCreated>
#                   <place>
#                      <placeTerm type="text">Warmsdorf</placeTerm>
#                   </place>
#                </originInfo>
#                <location>
#                   <shelfLocator>Chart. B 319, Bl. 69r-77r</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>9 Bl ; </extent>
#                </physicalDescription>
#                <note>Zur Datierung: Die Vorlage gibt das Jahr 1553 an. Es handelt sich aber offenbar um eine Predigt, die zu Weihnachten gehalten wurde. Dieser Tag galt damals als Beginn des neuen Kalenderjahrs. F&#252;rst Georg III. von Anhalt starb am 17.10.1553.</note>
#                <note type="editions">Georg (Anhalt, F&#252;rst, III.), Predigt von der Menschwerdung Christi, Bl. O4r-Q2v</note>
#                <note type="systemDetails">Nicht in EAD Vorhanden</note>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-3412353</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-3412353</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20061219</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20090218</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-06-19T04:19:49+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</recordContentSource>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-72207</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-72207</identifier>
#                   <titleInfo>
#                      <title>Auslegungssammlung zu Weihnachtsliedern</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-76593</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-76593</identifier>
#                   <titleInfo>
#                      <title>Nachlass Stephan Reich</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">mixed material</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/123624878">
#                   <namePart>Spangenberg, Johann (1484-1550)</namePart>
#                   <role>
#                      <roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</roleTerm>
#                      <roleTerm type="text" lang="ger">Verfasser</roleTerm>
#                   </role>
#                </name>
#                <subject>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4120567-4" authority="DE-588">Kirchenlied</topic>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4189434-0" authority="DE-588">Weihnachtslied</topic>
#                   <topic lang="ger" authority="DE-611">Gelobet seist du, Jesu Christ</topic>
#                </subject>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <titleInfo>
#                   <title>Auslegung des Liedes "Gelobet seist du Jesu Christ"</title>
#                </titleInfo>
#                <originInfo>
#                   <dateCreated encoding="w3cdtf" keyDate="yes" point="start">1544</dateCreated>
#                   <dateCreated>1544</dateCreated>
#                </originInfo>
#                <location>
#                   <shelfLocator>Chart. B 319, Bl. 176r-181v</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>6 Bl ; </extent>
#                </physicalDescription>
#                <note>Zur Datierung: Die Vorlage gibt das Jahr 1545 an. Es handelt sich aber offenbar um eine Predigt, die zu Weihnachten gehalten wurde. Dieser Tag galt damals als Beginn des neuen Kalenderjahrs. - Blatt 181v ist leer.</note>
#                <note type="systemDetails">Nicht in EAD Vorhanden</note>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-3412356</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-3412356</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20061218</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20090218</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T16:38:35+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</recordContentSource>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-72207</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-72207</identifier>
#                   <titleInfo>
#                      <title>Auslegungssammlung zu Weihnachtsliedern</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-76593</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-76593</identifier>
#                   <titleInfo>
#                      <title>Nachlass Stephan Reich</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">mixed material</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/123590736">
#                   <namePart>Reich, Stephan (1512-1588)</namePart>
#                   <role>
#                      <roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</roleTerm>
#                      <roleTerm type="text" lang="ger">Verfasser</roleTerm>
#                   </role>
#                </name>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/128403608">
#                   <namePart>Elisabeth, Sachsen, Herzogin (1540-1594)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">[Widmungsempf&#65533;ngerin] [nicht dokumentiert]</roleTerm>
#                   </role>
#                </name>
#                <subject>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4148981-0" authority="DE-588">Dedikation</topic>
#                   <topic lang="ger" authority="DE-611">Jesus Christus / Geburt</topic>
#                   <topic lang="ger" authority="DE-611">Jesus Christus / Taufe</topic>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4002230-4" authority="DE-588">Anthropologie</topic>
#                   <topic lang="ger" authority="DE-611">_swdts00020318</topic>
#                   <topic lang="ger" authority="DE-611">Rechtfertigungslehre</topic>
#                </subject>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4139988-2" authority="DE-588">Dokument</genre>
#                <titleInfo>
#                   <title>Widmungsvorrede der Predigtsammlung an Herzogin Elisabeth von Sachsen</title>
#                </titleInfo>
#                <originInfo>
#                   <dateCreated encoding="w3cdtf" keyDate="yes" point="start">1571-12-25</dateCreated>
#                   <dateCreated>25.12.1571</dateCreated>
#                   <place>
#                      <placeTerm type="text">Lissen</placeTerm>
#                   </place>
#                </originInfo>
#                <location>
#                   <shelfLocator>Chart. B 319, Bl. 1r-16r</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>16 Bl ; </extent>
#                </physicalDescription>
#                <note>Datierung: "am heiligen christtage 1572"</note>
#                <note type="systemDetails">Nicht in EAD Vorhanden</note>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-3412363</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-3412363</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20061219</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20090218</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T16:38:35+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</recordContentSource>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-72207</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-72207</identifier>
#                   <titleInfo>
#                      <title>Auslegungssammlung zu Weihnachtsliedern</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-76593</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-76593</identifier>
#                   <titleInfo>
#                      <title>Nachlass Stephan Reich</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">mixed material</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/123590736">
#                   <namePart>Reich, Stephan (1512-1588)</namePart>
#                   <role>
#                      <roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</roleTerm>
#                      <roleTerm type="text" lang="ger">Verfasser</roleTerm>
#                   </role>
#                </name>
#                <subject>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4120567-4" authority="DE-588">Kirchenlied</topic>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4189434-0" authority="DE-588">Weihnachtslied</topic>
#                   <topic lang="ger" authority="DE-611">Jesus Christus / Geburt</topic>
#                   <topic lang="ger" authority="DE-611">In dulci jubilo</topic>
#                </subject>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <titleInfo>
#                   <title>Auslegung des Liedes "In dulci jubilo"</title>
#                </titleInfo>
#                <originInfo>
#                   <dateCreated encoding="w3cdtf" keyDate="yes" point="start">1571</dateCreated>
#                   <dateCreated>1571 [[1571]]</dateCreated>
#                </originInfo>
#                <location>
#                   <shelfLocator>Chart. B 319, Bl. 77r-91v</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>15 Bl ; </extent>
#                </physicalDescription>
#                <note type="systemDetails">Nicht in EAD Vorhanden</note>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-3412367</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-3412367</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20061219</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20090218</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T16:38:35+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</recordContentSource>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-72207</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-72207</identifier>
#                   <titleInfo>
#                      <title>Auslegungssammlung zu Weihnachtsliedern</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-76593</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-76593</identifier>
#                   <titleInfo>
#                      <title>Nachlass Stephan Reich</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">mixed material</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/123590736">
#                   <namePart>Reich, Stephan (1512-1588)</namePart>
#                   <role>
#                      <roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</roleTerm>
#                      <roleTerm type="text" lang="ger">Verfasser</roleTerm>
#                   </role>
#                </name>
#                <subject>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4120567-4" authority="DE-588">Kirchenlied</topic>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4189434-0" authority="DE-588">Weihnachtslied</topic>
#                   <topic lang="ger" authority="DE-611">Vom Himmel hoch, da komm ich her</topic>
#                </subject>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <titleInfo>
#                   <title>Auslegung des Liedes "Vom Himmel hoch, da komm' ich her""</title>
#                </titleInfo>
#                <originInfo>
#                   <dateCreated encoding="w3cdtf" keyDate="yes" point="start">1571</dateCreated>
#                   <dateCreated>1571 [[1571]]</dateCreated>
#                </originInfo>
#                <location>
#                   <shelfLocator>Chart. B 319, Bl. 92r-136v</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>15 Bl ; </extent>
#                </physicalDescription>
#                <note>Blatt 136v ist leer.</note>
#                <note type="systemDetails">Nicht in EAD Vorhanden</note>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-3412368</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-3412368</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20061219</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20200117</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T16:38:35+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</recordContentSource>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-72207</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-72207</identifier>
#                   <titleInfo>
#                      <title>Auslegungssammlung zu Weihnachtsliedern</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-76593</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-76593</identifier>
#                   <titleInfo>
#                      <title>Nachlass Stephan Reich</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">mixed material</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/123590736">
#                   <namePart>Reich, Stephan (1512-1588)</namePart>
#                   <role>
#                      <roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</roleTerm>
#                      <roleTerm type="text" lang="ger">Verfasser</roleTerm>
#                   </role>
#                </name>
#                <subject>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4120567-4" authority="DE-588">Kirchenlied</topic>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4189434-0" authority="DE-588">Weihnachtslied</topic>
#                   <topic lang="ger" authority="DE-611">Grates nunc omnes</topic>
#                </subject>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <titleInfo>
#                   <title>Auslegung des Liedes "Grates nunc omnes"</title>
#                </titleInfo>
#                <originInfo>
#                   <dateCreated encoding="w3cdtf" keyDate="yes" point="start">1571</dateCreated>
#                   <dateCreated>1571 [ermittelt]</dateCreated>
#                </originInfo>
#                <location>
#                   <shelfLocator>Chart. B 319, Bl. 137r-175v</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>39 Bl ; </extent>
#                </physicalDescription>
#                <note type="systemDetails">Nicht in EAD Vorhanden</note>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-72210</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-BF-72210</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20070111</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20200120</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T16:38:35+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</recordContentSource>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-76593</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-76593</identifier>
#                   <titleInfo>
#                      <title>Nachlass Stephan Reich</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-76593</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-76593</identifier>
#                   <titleInfo>
#                      <title>Nachlass Stephan Reich</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">mixed material</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/123590736">
#                   <namePart>Reich, Stephan (1512-1588)</namePart>
#                   <role>
#                      <roleTerm type="text" lang="ger">Bestandsbildner</roleTerm>
#                   </role>
#                </name>
#                <titleInfo>
#                   <title>Reich, Stephan: Gebet und Auslegung von Psalm 37</title>
#                </titleInfo>
#                <originInfo>
#                   <dateCreated encoding="w3cdtf" keyDate="yes" point="start">1578</dateCreated>
#                   <dateCreated>1578</dateCreated>
#                </originInfo>
#                <location>
#                   <shelfLocator>Chart. B 316</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>1 Bd., 42 Bl. [insg. 43 Bl.] (Bl. 42 ist leer); 20,5 x 16,5 cm ; </extent>
#                </physicalDescription>
#                <note>Umschlag aus Papier und Pergamentmakulatur (Choralbuchblatt)</note>
#                <note type="systemDetails">Nicht in EAD Vorhanden</note>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
# ...
#                </mods:titleInfo>
#                <mods:originInfo>
#                   <mods:dateCreated encoding="w3cdtf" keyDate="yes" point="start">1537-10</mods:dateCreated>
#                   <mods:dateCreated>10.1537</mods:dateCreated>
#                   <mods:place>
#                      <mods:placeTerm type="text">[Wittenberg]</mods:placeTerm>
#                   </mods:place>
#                </mods:originInfo>
#                <mods:location>
#                   <mods:shelfLocator>Chart. A 357, Bl. 84r-89v</mods:shelfLocator>
#                   <mods:physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</mods:physicalLocation>
#                </mods:location>
#                <mods:physicalDescription>
#                   <mods:extent>6 Bl. ; </mods:extent>
#                </mods:physicalDescription>
#                <mods:note type="editions">Giovio, T&#252;rkisches Reich [VD 16 G 2051], Bl. A2r-C3v</mods:note>
#                <mods:note type="systemDetails">Nicht in EAD Vorhanden</mods:note>
#             </mods:mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods:mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <mods:identifier type="uri">https://kalliope-verbund.info/DE-611-HS-3419839</mods:identifier>
#                <mods:recordInfo>
#                   <mods:recordIdentifier source="DE-611">DE-611-HS-3419839</mods:recordIdentifier>
#                   <mods:recordCreationDate encoding="iso8601">20100907</mods:recordCreationDate>
#                   <mods:recordChangeDate encoding="iso8601">20190620</mods:recordChangeDate>
#                   <mods:recordChangeDate encoding="w3cdtf">2024-03-29T16:38:36+01:00</mods:recordChangeDate>
#                   <mods:recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</mods:recordContentSource>
#                </mods:recordInfo>
#                <mods:relatedItem type="host">
#                   <mods:recordInfo>
#                      <mods:recordIdentifier source="DE-611">DE-611-BF-72392</mods:recordIdentifier>
#                   </mods:recordInfo>
#                   <mods:identifier type="uri">https://kalliope-verbund.info/DE-611-BF-72392</mods:identifier>
#                   <mods:titleInfo>
#                      <mods:title>Sammlung zu den Ernestinern</mods:title>
#                   </mods:titleInfo>
#                </mods:relatedItem>
#                <mods:relatedItem type="series">
#                   <mods:recordInfo>
#                      <mods:recordIdentifier source="DE-611">DE-611-BF-76593</mods:recordIdentifier>
#                   </mods:recordInfo>
#                   <mods:identifier type="uri">https://kalliope-verbund.info/DE-611-BF-76593</mods:identifier>
#                   <mods:titleInfo>
#                      <mods:title>Nachlass Stephan Reich</mods:title>
#                   </mods:titleInfo>
#                </mods:relatedItem>
#                <mods:typeOfResource collection="yes">mixed material</mods:typeOfResource>
#                <mods:name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/119633949">
#                   <mods:namePart>Busmann, Johannes</mods:namePart>
#                   <mods:role>
#                      <mods:roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</mods:roleTerm>
#                      <mods:roleTerm type="text" lang="ger">Verfasser</mods:roleTerm>
#                   </mods:role>
#                </mods:name>
#                <mods:name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/120532549">
#                   <mods:namePart>Johann Ernst, Sachsen-Coburg, Herzog (1521-1553)</mods:namePart>
#                   <mods:role>
#                      <mods:roleTerm type="text" lang="ger">[Bezug] [nicht dokumentiert]</mods:roleTerm>
#                   </mods:role>
#                </mods:name>
#                <mods:subject>
#                   <mods:topic lang="ger" authority="DE-611">Epigramm</mods:topic>
#                </mods:subject>
#                <mods:genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</mods:genre>
#                <mods:titleInfo>
#                   <mods:title>Lobgedicht auf Herzog Johann Ernst von Sachsen</mods:title>
#                </mods:titleInfo>
#                <mods:originInfo>
#                   <mods:dateCreated encoding="w3cdtf" keyDate="yes" point="start">1537</mods:dateCreated>
#                   <mods:dateCreated>1537</mods:dateCreated>
#                </mods:originInfo>
#                <mods:location>
#                   <mods:shelfLocator>Chart. A 357, Bl. 89v-92r</mods:shelfLocator>
#                   <mods:physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</mods:physicalLocation>
#                </mods:location>
#                <mods:physicalDescription>
#                   <mods:extent>4 Bl. ; </mods:extent>
#                </mods:physicalDescription>
#                <mods:note type="editions">Johannes Busmann: Poemata quaedam, Wittenberg 1537, Bl. C4v-C8r</mods:note>
#                <mods:note type="systemDetails">Nicht in EAD Vorhanden</mods:note>
#             </mods:mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods:mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <mods:identifier type="uri">https://kalliope-verbund.info/DE-611-HS-3419840</mods:identifier>
#                <mods:recordInfo>
#                   <mods:recordIdentifier source="DE-611">DE-611-HS-3419840</mods:recordIdentifier>
#                   <mods:recordCreationDate encoding="iso8601">20101001</mods:recordCreationDate>
#                   <mods:recordChangeDate encoding="iso8601">20101001</mods:recordChangeDate>
#                   <mods:recordChangeDate encoding="w3cdtf">2024-03-29T16:38:36+01:00</mods:recordChangeDate>
#                   <mods:recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</mods:recordContentSource>
#                </mods:recordInfo>
#                <mods:relatedItem type="host">
#                   <mods:recordInfo>
#                      <mods:recordIdentifier source="DE-611">DE-611-BF-72392</mods:recordIdentifier>
#                   </mods:recordInfo>
#                   <mods:identifier type="uri">https://kalliope-verbund.info/DE-611-BF-72392</mods:identifier>
#                   <mods:titleInfo>
#                      <mods:title>Sammlung zu den Ernestinern</mods:title>
#                   </mods:titleInfo>
#                </mods:relatedItem>
#                <mods:relatedItem type="series">
#                   <mods:recordInfo>
#                      <mods:recordIdentifier source="DE-611">DE-611-BF-76593</mods:recordIdentifier>
#                   </mods:recordInfo>
#                   <mods:identifier type="uri">https://kalliope-verbund.info/DE-611-BF-76593</mods:identifier>
#                   <mods:titleInfo>
#                      <mods:title>Nachlass Stephan Reich</mods:title>
#                   </mods:titleInfo>
#                </mods:relatedItem>
#                <mods:typeOfResource collection="yes">mixed material</mods:typeOfResource>
#                <mods:name type="personal" authority="DE-611" authorityURI="https://kalliope-verbund.info/agents/" valueURI="https://kalliope-verbund.info/agents/179461">
#                   <mods:namePart>Unbekannt</mods:namePart>
#                   <mods:role>
#                      <mods:roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</mods:roleTerm>
#                      <mods:roleTerm type="text" lang="ger">Verfasser</mods:roleTerm>
#                   </mods:role>
#                </mods:name>
#                <mods:subject>
#                   <mods:topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4143477-8" authority="DE-588">Augsburger Interim</mods:topic>
#                   <mods:topic lang="ger" authority="DE-611">Pasquill</mods:topic>
#                </mods:subject>
#                <mods:genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</mods:genre>
#                <mods:titleInfo>
#                   <mods:title>Pasquillus de Interim 1548</mods:title>
#                </mods:titleInfo>
#                <mods:originInfo>
#                   <mods:dateCreated encoding="w3cdtf" keyDate="yes" point="start">1548</mods:dateCreated>
#                   <mods:dateCreated>1548</mods:dateCreated>
#                </mods:originInfo>
#                <mods:location>
#                   <mods:shelfLocator>Chart. A 357, Bl. 254v-255r</mods:shelfLocator>
#                   <mods:physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</mods:physicalLocation>
#                </mods:location>
#                <mods:physicalDescription>
#                   <mods:extent>2 Bl. ; </mods:extent>
#                </mods:physicalDescription>
#                <mods:note>Weitere Abschriften s. Chart. A 399, Bl. 90v-93v; Chart. B 23, Bl. 62r-63v. - Abschrift des Druckes.</mods:note>
#                <mods:note type="editions">Pasquillus</mods:note>
#                <mods:note type="systemDetails">Nicht in EAD Vorhanden</mods:note>
#             </mods:mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods:mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <mods:identifier type="uri">https://kalliope-verbund.info/DE-611-HS-3419842</mods:identifier>
#                <mods:recordInfo>
#                   <mods:recordIdentifier source="DE-611">DE-611-HS-3419842</mods:recordIdentifier>
#                   <mods:recordCreationDate encoding="iso8601">20100908</mods:recordCreationDate>
#                   <mods:recordChangeDate encoding="iso8601">20100908</mods:recordChangeDate>
#                   <mods:recordChangeDate encoding="w3cdtf">2024-05-03T22:44:30+01:00</mods:recordChangeDate>
#                   <mods:recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</mods:recordContentSource>
#                </mods:recordInfo>
#                <mods:relatedItem type="host">
#                   <mods:recordInfo>
#                      <mods:recordIdentifier source="DE-611">DE-611-BF-72392</mods:recordIdentifier>
#                   </mods:recordInfo>
#                   <mods:identifier type="uri">https://kalliope-verbund.info/DE-611-BF-72392</mods:identifier>
#                   <mods:titleInfo>
#                      <mods:title>Sammlung zu den Ernestinern</mods:title>
#                   </mods:titleInfo>
#                </mods:relatedItem>
#                <mods:relatedItem type="series">
#                   <mods:recordInfo>
#                      <mods:recordIdentifier source="DE-611">DE-611-BF-76593</mods:recordIdentifier>
#                   </mods:recordInfo>
#                   <mods:identifier type="uri">https://kalliope-verbund.info/DE-611-BF-76593</mods:identifier>
#                   <mods:titleInfo>
#                      <mods:title>Nachlass Stephan Reich</mods:title>
#                   </mods:titleInfo>
#                </mods:relatedItem>
#                <mods:typeOfResource collection="yes">mixed material</mods:typeOfResource>
#                <mods:name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/118785656">
#                   <mods:namePart>Naogeorgus, Thomas (1508-1563)</mods:namePart>
#                   <mods:role>
#                      <mods:roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</mods:roleTerm>
#                      <mods:roleTerm type="text" lang="ger">Verfasser</mods:roleTerm>
#                   </mods:role>
#                </mods:name>
#                <mods:name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/120532549">
#                   <mods:namePart>Johann Ernst, Sachsen-Coburg, Herzog (1521-1553)</mods:namePart>
#                   <mods:role>
#                      <mods:roleTerm type="text" lang="ger">[Bezug] [nicht dokumentiert]</mods:roleTerm>
#                   </mods:role>
#                </mods:name>
#                <mods:subject>
#                   <mods:topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4148981-0" authority="DE-588">Dedikation</mods:topic>
#                </mods:subject>
#                <mods:genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</mods:genre>
#                <mods:titleInfo>
#                   <mods:title>Widmungsvorrede an Herzog Johann Ernst von Sachsen [Auszug]</mods:title>
#                </mods:titleInfo>
#                <mods:originInfo>
#                   <mods:dateCreated encoding="w3cdtf" keyDate="yes" point="start">1544-03-16</mods:dateCreated>
#                   <mods:dateCreated>16.03.1544</mods:dateCreated>
#                   <mods:place>
#                      <mods:placeTerm type="text">Kahla</mods:placeTerm>
#                   </mods:place>
#                </mods:originInfo>
#                <mods:location>
#                   <mods:shelfLocator>Chart. A 357, Bl. 92r/v</mods:shelfLocator>
#                   <mods:physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-39">Forschungsbibliothek Gotha</mods:physicalLocation>
#                </mods:location>
#                <mods:physicalDescription>
#                   <mods:extent>1 Bl. ; </mods:extent>
#                </mods:physicalDescription>
#                <mods:note type="editions">Naogeorgus, In primam D. Ioannis Epistolam [VD 16 K 976], Bl. A4r-A5v</mods:note>
#                <mods:note type="systemDetails">Nicht in EAD Vorhanden</mods:note>
#             </mods:mods>
#          </srw:recordData>
#       </srw:record>
#    </srw:searchRetrieveResponse>

# %% [markdown]
# #### Parse data and convert to DataFrame
# records = records_xml.xpath("//srw:record", namespaces={"srw": "http://www.loc.gov/zing/srw/"})
# output = [parse_mods(record) for record in records]
# df = pd.DataFrame(output)
# df

# %% [markdown]
# # function parse mods
# def parse_mods(record):
#     ns = {
#         'srw': 'http://www.loc.gov/zing/srw/',  # SRW namespace
#         'mods': 'http://www.loc.gov/mods/v3'    # MODS namespace
#     }
#
#     # Extract the title (e.g., <titleInfo><title>)
#     title = record.xpath(".//mods:titleInfo/mods:title", namespaces=ns)
#     try:
#         title = title[0].text
#     except IndexError:
#         title = "unknown"
#
#     # Extract holder //mods/location/physicalLocation/@authority Physischer Standort (bestandshaltende Einrichtung)
#     holder = record.xpath(".//mods:location/mods:physicalLocation", namespaces=ns)
#     try:
#         holder = holder[0].text
#     except IndexError:
#         holder = "unknown"
#
#     # Extract ISIL //mods/location/physicalLocation/@authority Physischer Standort (bestandshaltende Einrichtung)
#     ISILholder = record.xpath(".//mods:location/mods:physicalLocation/@authorityURI", namespaces=ns)
#
#     lang_attributes = record.xpath("//@lang")
#
#     name = record.xpath(".//mods:namePart/text()", namespaces=ns)
#     nameID = record.xpath(".//mods:name/@authority", namespaces=ns)
#     abstract_content = record.xpath(".//mods:abstract[@type='content']/text()", namespaces=ns)
#     abstract_content = abstract_content[0] if abstract_content else 'NaN'
#
#     # XPath-Ausdruck zum Finden des leeren <title>-Tags
#     empty_titles = record.xpath("//mods:title[not(node())]", namespaces=ns)
#
#     # Ausgabe der leeren Titel
#     for title in empty_titles:
#         #print(f"Leerer <title>-Tag gefunden: {etree.tostring(title, pretty_print=True).decode()}")
#         print(f"Leerer <title>-Tag gefunden")
#
#
#
#     # Return a dictionary to build the DataFrame
#     return {
#         "Title": title,
#         "holder": holder,
#         "ISILholder": ISILholder,
#         "langattributes": lang_attributes,
#         "name": name,
#         "nameID": nameID,
#         "abstract_content": abstract_content,
#
#         # Add more fields to extract as needed
#
#
#     }
