# %% [markdown]
# # Kalliope SRU Abfrage und parsen von MODS mit Python etree
# Quelle: https://github.com/deutsche-nationalbibliothek/dnblab/blob/main/DNB_SRU_Tutorial.ipynb

# %%
import requests
from lxml import etree
import pandas as pd

# %%
# SRU query
def kalliope_sru(query):
    base_url = "https://kalliope-verbund.info/sru"
    params = {
        'version': '1.2',
        'operation': 'searchRetrieve',
        'recordSchema': 'mods37',
        'maximumRecords': '100',
        'query': query
    }
    
    r = requests.get(base_url, params=params)
    mods_content = r.content
    records_mods = etree.fromstring(mods_content)
    
    # Check if more than 100 records
    if len(records_mods.xpath("//srw:record", namespaces={'srw': 'http://www.loc.gov/zing/srw/'})) < 100:
        return records_xml
    else:
        num_results = 100
        i = 101
        while num_results == 100:
            params.update({'startRecord': i})
            r = requests.get(base_url, params=params)
            new_mods_content = r.content
            new_records_mods = etree.fromstring(new_mods_content)
            records_mods.extend(new_records_mods.xpath("//srw:record", namespaces={'srw': 'http://www.loc.gov/zing/srw/'}))
            i += 100
            num_results = len(new_records_mods.xpath("//srw:record", namespaces={'srw': 'http://www.loc.gov/zing/srw/'}))
        
        return records_mods

# %%
# function parse mods
def parse_mods(record):
    ns = {
        'srw': 'http://www.loc.gov/zing/srw/',  # SRW namespace
        'mods': 'http://www.loc.gov/mods/v3'    # MODS namespace
    }
    
    # Extract the title (e.g., <titleInfo><title>)
    title = record.xpath(".//mods:titleInfo/mods:title", namespaces=ns)
    try:
        title = title[0].text
    except IndexError:
        title = "unknown"
        
    # Extract holder //mods/location/physicalLocation/@authority Physischer Standort (bestandshaltende Einrichtung)
    holder = record.xpath(".//mods:location/mods:physicalLocation", namespaces=ns)    
    try:
        holder = holder[0].text
    except IndexError:
        holder = "unknown"
        
    # Extract ISIL //mods/location/physicalLocation/@authority Physischer Standort (bestandshaltende Einrichtung)
    ISILholder = record.xpath(".//mods:location/mods:physicalLocation/@authorityURI", namespaces=ns)
    
    lang_attributes = record.xpath("//@lang")
    
    name = record.xpath(".//mods:namePart/text()", namespaces=ns)
    nameID = record.xpath(".//mods:name/@authority", namespaces=ns)

   

    # Return a dictionary to build the DataFrame
    return {
        "Title": title,
        "holder": holder,
        "ISILholder": ISILholder,
        "langattributes": lang_attributes,
        "name": name,
        "nameID": nameID,
        
        # Add more fields to extract as needed
        
        
    }

# %%
# Example query
query = 'ead.id="DE-611-BF-110454"'
records_xml = kalliope_sru(query)

print(f'{len(records_xml.xpath("//srw:record", namespaces={"srw": "http://www.loc.gov/zing/srw/"}))} Ergebnisse gefunden')
# Out:
# 126 Ergebnisse gefunden

# %%
# Parse data and convert to DataFrame
records = records_xml.xpath("//srw:record", namespaces={"srw": "http://www.loc.gov/zing/srw/"})
output = [parse_mods(record) for record in records]
df = pd.DataFrame(output)
df
# Out:
#                         Title  \
# 0                        K. I
# 1                       K. II
# 2                      K. III
# 3                       K. IV
# 4                       K. IV
# ..                        ...
# 121         Kurt Wolff Archiv
# 122  Chronologische Konvolute
# 123  Chronologische Konvolute
# 124  Chronologische Konvolute
# 125  Chronologische Konvolute
#
#                                                 holder  \
# 0    Staatsbibliothek zu Berlin. Handschriftenabtei...
# 1    Staatsbibliothek zu Berlin. Handschriftenabtei...
# 2    Staatsbibliothek zu Berlin. Handschriftenabtei...
# 3    Staatsbibliothek zu Berlin. Handschriftenabtei...
# 4    Staatsbibliothek zu Berlin. Handschriftenabtei...
# ..                                                 ...
# 121  Yale University, Beinecke Rare Book and Manusc...
# 122              Schweizerisches Literaturarchiv (SLA)
# 123              Schweizerisches Literaturarchiv (SLA)
# 124              Schweizerisches Literaturarchiv (SLA)
# 125              Schweizerisches Literaturarchiv (SLA)
#
#                                             ISILholder  \
# 0    [http://ld.zdb-services.de/resource/organisati...
# 1    [http://ld.zdb-services.de/resource/organisati...
# 2    [http://ld.zdb-services.de/resource/organisati...
# 3    [http://ld.zdb-services.de/resource/organisati...
# 4    [http://ld.zdb-services.de/resource/organisati...
# ..                                                 ...
# 121  [http://ld.zdb-services.de/resource/organisati...
# 122  [http://ld.zdb-services.de/resource/organisati...
# 123  [http://ld.zdb-services.de/resource/organisati...
# 124  [http://ld.zdb-services.de/resource/organisati...
# 125  [http://ld.zdb-services.de/resource/organisati...
#
#                                         langattributes  \
# 0    [eng, ger, ger, ger, ger, eng, ger, ger, ger, ...
# 1    [eng, ger, ger, ger, ger, eng, ger, ger, ger, ...
# 2    [eng, ger, ger, ger, ger, eng, ger, ger, ger, ...
# 3    [eng, ger, ger, ger, ger, eng, ger, ger, ger, ...
# 4    [eng, ger, ger, ger, ger, eng, ger, ger, ger, ...
# ..                                                 ...
# 121  [eng, ger, ger, ger, ger, eng, ger, ger, ger, ...
# 122  [eng, ger, ger, ger, ger, eng, ger, ger, ger, ...
# 123  [eng, ger, ger, ger, ger, eng, ger, ger, ger, ...
# 124  [eng, ger, ger, ger, ger, eng, ger, ger, ger, ...
# 125  [eng, ger, ger, ger, ger, eng, ger, ger, ger, ...
#
#                                                   name  \
# 0                                        [Mann, Oskar]
# 1                                        [Mann, Oskar]
# 2                                        [Mann, Oskar]
# 3                                        [Mann, Oskar]
# 4                                        [Mann, Oskar]
# ..                                                 ...
# 121  [Benn, Gottfried (1886-1956), Heym, Georg (188...
# 122  [Schweizerisches Literaturarchiv (SLA), Mann, ...
# 123  [Schweizerisches Literaturarchiv (SLA), Speer,...
# 124  [Schweizerisches Literaturarchiv (SLA), May, F...
# 125  [Schweizerisches Literaturarchiv (SLA), Meyer,...
#
#                                                 nameID
# 0                                             [DE-588]
# 1                                             [DE-588]
# 2                                             [DE-588]
# 3                                             [DE-588]
# 4                                             [DE-588]
# ..                                                 ...
# 121  [DE-588, DE-588, DE-588, DE-588, DE-588, DE-58...
# 122  [DE-588, DE-588, DE-588, DE-588, DE-588, DE-58...
# 123  [DE-588, DE-588, DE-588, DE-588, DE-588, DE-58...
# 124  [DE-588, DE-588, DE-588, DE-588, DE-588, DE-58...
# 125  [DE-588, DE-588, DE-588, DE-588, DE-588, DE-58...
#
# [126 rows x 6 columns]

# %%
print(etree.tostring(records_xml, pretty_print=True).decode())
# Out:
# <srw:searchRetrieveResponse xmlns:srw="http://www.loc.gov/zing/srw/" xmlns:srw_dc="info:srw/schema/1/dc-v1.1" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:diag="http://www.loc.gov/zing/srw/diagnostic/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:mods="http://www.loc.gov/mods/v3" xmlns:cld="http://www.ukoln.ac.uk/metadata/rslp/schema/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:my="http://www.infolytics.com/kopac" xmlns:eacNS="urn:isbn:1-931666-33-4">
#    <srw:version>1.2</srw:version>
#    <srw:numberOfRecords>126</srw:numberOfRecords>
#    <srw:records>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-1781756</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-1781756</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20120223</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20120615</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T15:26:18+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-1a">Staatsbibliothek zu Berlin. Handschriftenabteilung</recordContentSource>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-24720</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-24720</identifier>
#                   <titleInfo>
#                      <title>K. I</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-2978</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-2978</identifier>
#                   <titleInfo>
#                      <title>Nachl. Oskar Mann</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">text</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/116943009">
#                   <namePart>Mann, Oskar</namePart>
#                   <role>
#                      <roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</roleTerm>
#                      <roleTerm type="text" lang="ger">Verfasser</roleTerm>
#                   </role>
#                </name>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4125430-2" authority="DE-588">Zeitungsartikel</genre>
#                <titleInfo>
#                   <title>Deutsche BankKonzession in Persien (Incipit der Unterlage)</title>
#                </titleInfo>
#                <abstract type="content">Entwurf eines Beitrages &#252;ber die deutsche Bankkonzession in Persien. Von O. Mann im Jahre 1908 geschrieben und auch in der K&#246;lner Zeitung ver&#246;ffentlicht. Siehe Literaturhinweis.</abstract>
#                <originInfo>
#                   <dateCreated encoding="w3cdtf" keyDate="yes" point="start">1908</dateCreated>
#                   <dateCreated>1908</dateCreated>
#                   <place>
#                      <placeTerm type="text">Berlin</placeTerm>
#                   </place>
#                </originInfo>
#                <language>
#                   <languageTerm authority="iso639-2b" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/ger" type="code">ger</languageTerm>
#                   <languageTerm type="text" lang="ger">Deutsch</languageTerm>
#                </language>
#                <location>
#                   <shelfLocator>Nachl. Oskar Mann, K. I, Mp. 12</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-1a">Staatsbibliothek zu Berlin. Handschriftenabteilung</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>6 Bl. neu foliiert ; </extent>
#                </physicalDescription>
#                <note type="publications">In: K&#246;lner Zeitung, Nr. 20. vom 7. Januar 1908 (Morgen Ausgabe)</note>
#                <note type="systemDetails">Handschrift</note>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-1696520</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-1696520</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20100819</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20120615</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T15:26:18+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-1a">Staatsbibliothek zu Berlin. Handschriftenabteilung</recordContentSource>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-24721</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-24721</identifier>
#                   <titleInfo>
#                      <title>K. II</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-2978</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-2978</identifier>
#                   <titleInfo>
#                      <title>Nachl. Oskar Mann</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">text</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/116943009">
#                   <namePart>Mann, Oskar</namePart>
#                   <role>
#                      <roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</roleTerm>
#                      <roleTerm type="text" lang="ger">Verfasser</roleTerm>
#                   </role>
#                </name>
#                <subject>
#                   <topic lang="ger" authority="DE-611">Kultur</topic>
#                   <topic lang="ger" authority="DE-611">Iranistik</topic>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4035964-5" authority="DE-588">Literatur</topic>
#                </subject>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4206777-7" authority="DE-588">Notiz</genre>
#                <titleInfo>
#                   <title>Persische Sprichw&#246;rter (umgangsssprachlich) (Ansetzungssachtitel von Bearbeiter/in)</title>
#                </titleInfo>
#                <abstract type="content">Etliche Notizen (auf unterschiedlichem Papierformat) betreffend Sprichw&#246;rter der persischen Umgangssprache. Sprichw&#246;rter und Redewendungen aus Kunst und Poesie oder daraus abgeleitete sind hier nicht zu finden. Alle Spr&#252;che und Redensarten sind auf Persisch geschrieben und zwar von unterschiedlichen Personen, darunter auch viele Perser geschrieben, jedoch auch viele von der Hand O. Manns. Dazwischen viele Notizen und &#220;bersetzungen auf Deutsch und Englisch. Die Erkl&#228;rungen sind fast alle auf Deutsch und Englisch von O. Mann geschrieben.
# Die Sprichw&#246;rter haben folgende Unterteilung:
# 1. Eigentliche Sprichw&#246;rter
# 2. Bildliche Redewendungen
# 3. Bildliche Umschreibungen von menschlichen Eigenschaften
# 4. Lexikalisches und einfache Spr&#252;che</abstract>
#                <originInfo>
#                   <dateCreated encoding="w3cdtf" keyDate="yes" point="start">1905</dateCreated>
#                   <dateCreated encoding="w3cdtf" point="end">1915</dateCreated>
#                   <dateCreated>1905-1915</dateCreated>
#                   <place>
#                      <placeTerm type="text">Berlin</placeTerm>
#                   </place>
#                </originInfo>
#                <language>
#                   <languageTerm authority="iso639-2b" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/ger" type="code">ger</languageTerm>
#                   <languageTerm type="text" lang="ger">Deutsch</languageTerm>
#                </language>
#                <language>
#                   <languageTerm authority="iso639-2b" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/per" type="code">per</languageTerm>
#                   <languageTerm type="text" lang="ger">Persisch</languageTerm>
#                </language>
#                <language>
#                   <languageTerm authority="iso639-2b" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/eng" type="code">eng</languageTerm>
#                   <languageTerm type="text" lang="ger">Englisch</languageTerm>
#                </language>
#                <location>
#                   <shelfLocator>Nachl. Oskar Mann, K. II, Mp. 1</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-1a">Staatsbibliothek zu Berlin. Handschriftenabteilung</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>57 Bl. teilw. beidseitig beschrieben, neu foliiert ; </extent>
#                </physicalDescription>
#                <note type="systemDetails">Handschrift</note>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-1696808</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-1696808</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20100824</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20120711</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T15:26:18+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-1a">Staatsbibliothek zu Berlin. Handschriftenabteilung</recordContentSource>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-24722</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-24722</identifier>
#                   <titleInfo>
#                      <title>K. III</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-2978</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-2978</identifier>
#                   <titleInfo>
#                      <title>Nachl. Oskar Mann</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">text</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/116943009">
#                   <namePart>Mann, Oskar</namePart>
#                   <role>
#                      <roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</roleTerm>
#                      <roleTerm type="text" lang="ger">Verfasser</roleTerm>
#                   </role>
#                </name>
#                <subject>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4114333-4" authority="DE-588">Kunst</topic>
#                   <topic lang="ger" authority="DE-611">Buch</topic>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4122782-7" authority="DE-588">Alltagskultur</topic>
#                </subject>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/1033469920" authority="DE-588">Zettelkasten</genre>
#                <titleInfo>
#                   <title>Zettelkasten zu persischen und indischen Miniaturen (Ansetzungssachtitel von Bearbeiter/in)</title>
#                </titleInfo>
#                <abstract type="content">Aufzeichnungen von Oskar Mann bzw. eine Bestandsaufnahme persischer und indischer Miniaturen, die sich in den Handschriften der K&#246;nigl. Bibliothek in Berlin finden. Zettelkasten mit Daten zu den Miniaturen wie Quelle (welche Handschrift) mit Signatur und Seite, Datierung, Ort, Titel, Ma&#223;e, Bildbeschreibung.
# Es finden sich auch Hinweise zu anderen Sammlungen und Bibliotheken wie: Institut des Langues orientales, Freiherr von Lipperheidesche B&#252;chersammlung in Berlin, St. Petersburger Bibliothek, British Museum usw. Die Angaben sind auf unterscheidlichem Papierformat geschrieben.</abstract>
#                <originInfo>
#                   <dateCreated encoding="w3cdtf" keyDate="yes" point="start">1900</dateCreated>
#                   <dateCreated encoding="w3cdtf" point="end">1917</dateCreated>
#                   <dateCreated>1900-1917</dateCreated>
#                   <place>
#                      <placeTerm type="text">Berlin</placeTerm>
#                   </place>
#                </originInfo>
#                <language>
#                   <languageTerm authority="iso639-2b" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/ger" type="code">ger</languageTerm>
#                   <languageTerm type="text" lang="ger">Deutsch</languageTerm>
#                </language>
#                <language>
#                   <languageTerm authority="iso639-2b" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/per" type="code">per</languageTerm>
#                   <languageTerm type="text" lang="ger">Persisch</languageTerm>
#                </language>
#                <language>
#                   <languageTerm authority="iso639-2b" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/eng" type="code">eng</languageTerm>
#                   <languageTerm type="text" lang="ger">Englisch</languageTerm>
#                </language>
#                <location>
#                   <shelfLocator>Nachl. Oskar Mann, K. III, Mp. 2</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-1a">Staatsbibliothek zu Berlin. Handschriftenabteilung</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>90 Bl. Beidseitig beschrieben, neu foliiert ; </extent>
#                </physicalDescription>
#                <note type="systemDetails">Handschrift</note>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-1699119</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-1699119</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20100909</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20120711</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T15:26:18+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-1a">Staatsbibliothek zu Berlin. Handschriftenabteilung</recordContentSource>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-24723</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-24723</identifier>
#                   <titleInfo>
#                      <title>K. IV</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-2978</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-2978</identifier>
#                   <titleInfo>
#                      <title>Nachl. Oskar Mann</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">text</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/116943009">
#                   <namePart>Mann, Oskar</namePart>
#                   <role>
#                      <roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</roleTerm>
#                      <roleTerm type="text" lang="ger">Verfasser</roleTerm>
#                   </role>
#                </name>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4279136-4" authority="DE-588">Abschrift</genre>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4061418-9" authority="DE-588">&#220;bersetzung</genre>
#                <titleInfo>
#                   <title>Die Geschichte Persiens im 18. Jahrhundert (Ansetzungssachtitel von Bearbeiter/in)</title>
#                </titleInfo>
#                <abstract type="content">Abschrift und &#220;bersetzungen aus dem Werk "Die Geschichte des Ahmedschadi Durrani". Daneben Material und Quellensammlung zum Thema. O.Mann liefert eine eine chronologische Beschreibung vor allem &#252;ber die indischen Feldz&#252;ge.</abstract>
#                <originInfo>
#                   <dateCreated encoding="w3cdtf" keyDate="yes" point="start">1890</dateCreated>
#                   <dateCreated>1890</dateCreated>
#                   <place>
#                      <placeTerm type="text">Berlin</placeTerm>
#                   </place>
#                </originInfo>
#                <language>
#                   <languageTerm authority="iso639-2b" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/per" type="code">per</languageTerm>
#                   <languageTerm type="text" lang="ger">Persisch</languageTerm>
#                </language>
#                <language>
#                   <languageTerm authority="iso639-2b" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/ger" type="code">ger</languageTerm>
#                   <languageTerm type="text" lang="ger">Deutsch</languageTerm>
#                </language>
#                <location>
#                   <shelfLocator>Nachl. Oskar Mann, K. IV, Mp. 2</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-1a">Staatsbibliothek zu Berlin. Handschriftenabteilung</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>45 Blatt, beidseitig beschriftet, neu foliiert ; </extent>
#                </physicalDescription>
#                <note type="publications">Das Mujmil et Tarihk-i badnadirije des Ibn-Muhammad Emin Abul Hasan aus Gulistane / nach der Berliner Handschrift herausgegeben und mit einem Vorwort versehen von Oskar Mann: Leiden: Brill, 1896</note>
#                <note type="systemDetails">Handschrift</note>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-1699120</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-1699120</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20100909</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20120711</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T15:26:18+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-1a">Staatsbibliothek zu Berlin. Handschriftenabteilung</recordContentSource>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-24723</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-24723</identifier>
#                   <titleInfo>
#                      <title>K. IV</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-2978</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-2978</identifier>
#                   <titleInfo>
#                      <title>Nachl. Oskar Mann</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">text</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/116943009">
#                   <namePart>Mann, Oskar</namePart>
#                   <role>
#                      <roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</roleTerm>
#                      <roleTerm type="text" lang="ger">Verfasser</roleTerm>
#                   </role>
#                </name>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4279136-4" authority="DE-588">Abschrift</genre>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4206777-7" authority="DE-588">Notiz</genre>
#                <titleInfo>
#                   <title>Quellenmaterial zur Geschichte Indiens nach 1747 (Ansetzungssachtitel von Bearbeiter/in)</title>
#                </titleInfo>
#                <abstract type="content">Abschrift und &#220;bersetzungen aus dem Werk "Die Geschichte des Ahmedschadi Durrani". Daneben Material und Quellensammlung zum Thema. O. Mann liefert eine chronologische Beschreibung vor allem der indischen Feldz&#252;ge.</abstract>
#                <originInfo>
#                   <dateCreated encoding="w3cdtf" keyDate="yes" point="start">1890</dateCreated>
#                   <dateCreated>1890</dateCreated>
#                   <place>
#                      <placeTerm type="text">Berlin</placeTerm>
#                   </place>
#                </originInfo>
#                <language>
#                   <languageTerm authority="iso639-2b" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/per" type="code">per</languageTerm>
#                   <languageTerm type="text" lang="ger">Persisch</languageTerm>
#                </language>
#                <language>
#                   <languageTerm authority="iso639-2b" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/ger" type="code">ger</languageTerm>
#                   <languageTerm type="text" lang="ger">Deutsch</languageTerm>
#                </language>
#                <language>
#                   <languageTerm authority="iso639-2b" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/eng" type="code">eng</languageTerm>
#                   <languageTerm type="text" lang="ger">Englisch</languageTerm>
#                </language>
#                <location>
#                   <shelfLocator>Nachl. Oskar Mann, K. IV, Mp. 3</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-1a">Staatsbibliothek zu Berlin. Handschriftenabteilung</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>12 Blatt, beidseitig beschriftet, neu foliiert ; </extent>
#                </physicalDescription>
#                <note type="publications">Das Mujmil et Tarihk-i badnadirije des Ibn-Muhammad Emin Abul Hasan aus Gulistane / nach der Berliner Handschriften Herausgegeben und mit einem Vorwort versehen von Oskar Mann: Leiden: Brill, 1896</note>
#                <note type="systemDetails">Handschrift</note>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-1699121</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-1699121</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20100909</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20120711</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T15:26:18+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-1a">Staatsbibliothek zu Berlin. Handschriftenabteilung</recordContentSource>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-24723</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-24723</identifier>
#                   <titleInfo>
#                      <title>K. IV</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-2978</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-2978</identifier>
#                   <titleInfo>
#                      <title>Nachl. Oskar Mann</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">text</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/116943009">
#                   <namePart>Mann, Oskar</namePart>
#                   <role>
#                      <roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</roleTerm>
#                      <roleTerm type="text" lang="ger">Verfasser</roleTerm>
#                   </role>
#                </name>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4279136-4" authority="DE-588">Abschrift</genre>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4061418-9" authority="DE-588">&#220;bersetzung</genre>
#                <titleInfo>
#                   <title>Indische Feldz&#252;ge des Ahmedschah nach Emins Darstellung (Ansetzungssachtitel von Bearbeiter/in)</title>
#                </titleInfo>
#                <abstract type="content">Abschrift und &#220;bersetzungen aus dem Werk.</abstract>
#                <originInfo>
#                   <dateCreated encoding="w3cdtf" keyDate="yes" point="start">1890</dateCreated>
#                   <dateCreated encoding="w3cdtf" point="end">1895</dateCreated>
#                   <dateCreated>1890-1895</dateCreated>
#                   <place>
#                      <placeTerm type="text">Berlin</placeTerm>
#                   </place>
#                </originInfo>
#                <language>
#                   <languageTerm authority="iso639-2b" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/per" type="code">per</languageTerm>
#                   <languageTerm type="text" lang="ger">Persisch</languageTerm>
#                </language>
#                <language>
#                   <languageTerm authority="iso639-2b" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/ger" type="code">ger</languageTerm>
#                   <languageTerm type="text" lang="ger">Deutsch</languageTerm>
#                </language>
#                <location>
#                   <shelfLocator>Nachl. Oskar Mann, K. IV, Mp. 4</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-1a">Staatsbibliothek zu Berlin. Handschriftenabteilung</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>4 Blatt, beidseitig beschriftet, neu foliiert ; </extent>
#                </physicalDescription>
#                <note type="publications">Das Mujmil et Tarihk-i badnadirije des Ibn-Muhammad Emin Abul Hasan aus Gulistane / nach der Berliner Handschrift herausgegeben und mit einem Vorwort versehen von Oskar Mann: Leiden: Brill, 1896</note>
#                <note type="systemDetails">Handschrift</note>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-1699122</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-1699122</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20100909</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20120711</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T15:26:18+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-1a">Staatsbibliothek zu Berlin. Handschriftenabteilung</recordContentSource>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-24723</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-24723</identifier>
#                   <titleInfo>
#                      <title>K. IV</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-2978</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-2978</identifier>
#                   <titleInfo>
#                      <title>Nachl. Oskar Mann</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">text</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/116943009">
#                   <namePart>Mann, Oskar</namePart>
#                   <role>
#                      <roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</roleTerm>
#                      <roleTerm type="text" lang="ger">Verfasser</roleTerm>
#                   </role>
#                </name>
#                <subject>
#                   <topic lang="ger" authority="DE-611">Iranistik</topic>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4020517-4" authority="DE-588">Geschichte</topic>
#                </subject>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4206777-7" authority="DE-588">Notiz</genre>
#                <titleInfo>
#                   <title>Notizen zu persischen und afghanischen M&#252;nzen im 18. Jahrhundert (Ansetzungssachtitel von Bearbeiter/in)</title>
#                </titleInfo>
#                <abstract type="content">Angaben zu M&#252;nzen verschiedener Herrscher des 18. Jahrhunderts mit Daten, Ort und weiteren Details, die sich auf der Vorder- und der R&#252;ckseite der M&#252;nzen befinden. Teilweise sind die Daten chronologisch geordnet. Es finden sich auch Hinweise zu Museen und Sammlungen</abstract>
#                <originInfo>
#                   <dateCreated encoding="w3cdtf" keyDate="yes" point="start">1890</dateCreated>
#                   <dateCreated encoding="w3cdtf" point="end">1895</dateCreated>
#                   <dateCreated>1890-1895</dateCreated>
#                   <place>
#                      <placeTerm type="text">Berlin</placeTerm>
#                   </place>
#                </originInfo>
#                <language>
#                   <languageTerm authority="iso639-2b" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/per" type="code">per</languageTerm>
#                   <languageTerm type="text" lang="ger">Persisch</languageTerm>
#                </language>
#                <language>
#                   <languageTerm authority="iso639-2b" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/ger" type="code">ger</languageTerm>
#                   <languageTerm type="text" lang="ger">Deutsch</languageTerm>
#                </language>
#                <language>
#                   <languageTerm authority="iso639-2b" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/eng" type="code">eng</languageTerm>
#                   <languageTerm type="text" lang="ger">Englisch</languageTerm>
#                </language>
#                <location>
#                   <shelfLocator>Nachl. Oskar Mann, K. IV, Mp. 5</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-1a">Staatsbibliothek zu Berlin. Handschriftenabteilung</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>18 Blatt, beidseitig beschriftet, neu foliiert ; </extent>
#                </physicalDescription>
#                <note type="systemDetails">Handschrift</note>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-1699127</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-1699127</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20100909</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20120711</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T15:26:18+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-1a">Staatsbibliothek zu Berlin. Handschriftenabteilung</recordContentSource>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-24723</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-24723</identifier>
#                   <titleInfo>
#                      <title>K. IV</title>
#                   </titleInfo>
#                </relatedItem>
#                <relatedItem type="series">
#                   <recordInfo>
#                      <recordIdentifier source="DE-611">DE-611-BF-2978</recordIdentifier>
#                   </recordInfo>
#                   <identifier type="uri">https://kalliope-verbund.info/DE-611-BF-2978</identifier>
#                   <titleInfo>
#                      <title>Nachl. Oskar Mann</title>
#                   </titleInfo>
#                </relatedItem>
#                <typeOfResource collection="yes">text</typeOfResource>
#                <name type="personal" authority="DE-588" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/116943009">
#                   <namePart>Mann, Oskar</namePart>
#                   <role>
#                      <roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</roleTerm>
#                      <roleTerm type="text" lang="ger">Verfasser</roleTerm>
#                   </role>
#                </name>
#                <subject>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4020517-4" authority="DE-588">Geschichte</topic>
#                   <topic lang="ger" authority="DE-611">Iranistik</topic>
#                   <topic lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4020216-1" authority="DE-588">Geografie</topic>
#                </subject>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4117633-9" authority="DE-588">Werk</genre>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4279136-4" authority="DE-588">Abschrift</genre>
#                <genre lang="ger" authorityURI="https://d-nb.info/gnd/" valueURI="https://d-nb.info/gnd/4136710-8" authority="DE-588">Kommentar</genre>
#                <titleInfo>
#                   <title>Abschrift aus dem Geschichtswerk Majma el tawarikh von Khalil (Ansetzungssachtitel von Bearbeiter/in)</title>
#                </titleInfo>
#                <abstract type="content">Oskar Mann schreibt stellenweise aus dem Werk ab und gibt Hinweise und Kommentare auf Deutsch dazu.</abstract>
#                <originInfo>
#                   <dateCreated encoding="w3cdtf" keyDate="yes" point="start">1888</dateCreated>
#                   <dateCreated encoding="w3cdtf" point="end">1890</dateCreated>
#                   <dateCreated>1888-1890</dateCreated>
#                   <place>
#                      <placeTerm type="text">Berlin</placeTerm>
#                   </place>
#                </originInfo>
#                <language>
#                   <languageTerm authority="iso639-2b" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/per" type="code">per</languageTerm>
#                   <languageTerm type="text" lang="ger">Persisch</languageTerm>
#                </language>
#                <language>
#                   <languageTerm authority="iso639-2b" authorityURI="http://id.loc.gov/vocabulary/iso639-2/" valueURI="http://id.loc.gov/vocabulary/iso639-2/ger" type="code">ger</languageTerm>
#                   <languageTerm type="text" lang="ger">Deutsch</languageTerm>
#                </language>
#                <location>
#                   <shelfLocator>Nachl. Oskar Mann, K. IV, Mp. 7</shelfLocator>
#                   <physicalLocation authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-1a">Staatsbibliothek zu Berlin. Handschriftenabteilung</physicalLocation>
#                </location>
#                <physicalDescription>
#                   <extent>21 Blatt, nebst Umschlag beidseitig beschriftet, neu foliiert ; </extent>
#                </physicalDescription>
#                <note type="publications">[Geschichte Persiens in den Jahren 1747-1750. Bd. I.] Das Mujmil et Tarihk-i badnadirije des Ibn-Muhammad Emin Abul Hasan aus Gulistane / Oskar Mann: Leiden: Brill, 1891</note>
#                <note type="systemDetails">Handschrift</note>
#             </mods>
#          </srw:recordData>
#       </srw:record>
#       <srw:record>
#          <srw:recordSchema>info:srw/schema/1/mods-v3.7</srw:recordSchema>
#          <srw:recordPacking>xml</srw:recordPacking>
#          <srw:recordData>
#             <mods xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 https://www.loc.gov/standards/mods/v3/mods-3-7.xsd">
#                <identifier type="uri">https://kalliope-verbund.info/DE-611-HS-1699128</identifier>
#                <recordInfo>
#                   <recordIdentifier source="DE-611">DE-611-HS-1699128</recordIdentifier>
#                   <recordCreationDate encoding="iso8601">20100909</recordCreationDate>
#                   <recordChangeDate encoding="iso8601">20120711</recordChangeDate>
#                   <recordChangeDate encoding="w3cdtf">2024-03-29T15:26:18+01:00</recordChangeDate>
#                   <recordContentSource authority="German ISIL- and Library Codes Agency" authorityURI="http://ld.zdb-services.de/resource/organisations/" valueURI="http://ld.zdb-services.de/resource/organisations/DE-1a">Staatsbibliothek zu Berlin. Handschriftenabteilung</recordContentSource>
#                </recordInfo>
#                <relatedItem type="host">
#                   <recordInfo>
# ...
#                <mods:name type="corporate">
#                   <mods:namePart>&#214;sterreichische Urania f&#252;r Steiermark</mods:namePart>
#                   <mods:role>
#                      <mods:roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</mods:roleTerm>
#                      <mods:roleTerm type="text" lang="ger">Verfasser</mods:roleTerm>
#                   </mods:role>
#                </mods:name>
#                <mods:name type="corporate">
#                   <mods:namePart>&#214;sterreichische Urania f&#252;r Steiermark</mods:namePart>
#                   <mods:role>
#                      <mods:roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/rcp">rcp</mods:roleTerm>
#                      <mods:roleTerm type="text" lang="ger">Adressat</mods:roleTerm>
#                   </mods:role>
#                </mods:name>
#                <mods:name type="corporate">
#                   <mods:namePart>Schweizerische Hochschulrektorenkonferenz</mods:namePart>
#                   <mods:role>
#                      <mods:roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</mods:roleTerm>
#                      <mods:roleTerm type="text" lang="ger">Verfasser</mods:roleTerm>
#                   </mods:role>
#                </mods:name>
#                <mods:name type="corporate">
#                   <mods:namePart>Schweizerische Hochschulrektorenkonferenz</mods:namePart>
#                   <mods:role>
#                      <mods:roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/rcp">rcp</mods:roleTerm>
#                      <mods:roleTerm type="text" lang="ger">Adressat</mods:roleTerm>
#                   </mods:role>
#                </mods:name>
#                <mods:name type="corporate">
#                   <mods:namePart>Festspiele Europ&#228;ische Wochen Passau e.V.</mods:namePart>
#                   <mods:role>
#                      <mods:roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</mods:roleTerm>
#                      <mods:roleTerm type="text" lang="ger">Verfasser</mods:roleTerm>
#                   </mods:role>
#                </mods:name>
#                <mods:name type="corporate">
#                   <mods:namePart>Festspiele Europ&#228;ische Wochen Passau e.V.</mods:namePart>
#                   <mods:role>
#                      <mods:roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/rcp">rcp</mods:roleTerm>
#                      <mods:roleTerm type="text" lang="ger">Adressat</mods:roleTerm>
#                   </mods:role>
#                </mods:name>
#                <mods:name type="corporate">
#                   <mods:namePart>Privathilfe f&#252;r K&#252;nstler in Bayern</mods:namePart>
#                   <mods:role>
#                      <mods:roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/cre">cre</mods:roleTerm>
#                      <mods:roleTerm type="text" lang="ger">Verfasser</mods:roleTerm>
#                   </mods:role>
#                </mods:name>
#                <mods:name type="corporate">
#                   <mods:namePart>Privathilfe f&#252;r K&#252;nstler in Bayern</mods:namePart>
#                   <mods:role>
#                      <mods:roleTerm authority="MARC Code List for Relators Scheme" authorityURI="http://id.loc.gov/vocabulary/relators/" type="code" lang="eng" valueURI="http://id.loc.gov/vocabulary/relators/rcp">rcp</mods:roleTerm>
#                      <mods:roleTerm type="text" lang="ger">Adressat</mods:roleTerm>
#                   </mods:role>
#                </mods:name>
#                <mods:name type="corporate">
#                   <mods:namePart>